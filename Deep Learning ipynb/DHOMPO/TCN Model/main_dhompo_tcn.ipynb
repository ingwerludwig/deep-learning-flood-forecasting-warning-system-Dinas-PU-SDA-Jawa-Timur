# %% [markdown]
# # Import Dependensi

# %%
# !pip install keras-tcn
# Out:
# Collecting keras-tcn
#   Downloading keras_tcn-3.5.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-tcn) (1.23.5)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from keras-tcn) (2.13.0)
# Collecting tensorflow-addons (from keras-tcn)
#   Downloading tensorflow_addons-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (612 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.1/612.1 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.59.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.9.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.13.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.16.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.13.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.34.0)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons->keras-tcn)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow->keras-tcn) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow->keras-tcn) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow->keras-tcn) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow->keras-tcn) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow->keras-tcn) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow->keras-tcn) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow->keras-tcn) (3.0.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow->keras-tcn) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow->keras-tcn) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow->keras-tcn) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow->keras-tcn) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow->keras-tcn) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow->keras-tcn) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow->keras-tcn) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow->keras-tcn) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow->keras-tcn) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow->keras-tcn) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow->keras-tcn) (3.2.2)
# Installing collected packages: typeguard, tensorflow-addons, keras-tcn
# Successfully installed keras-tcn-3.5.0 tensorflow-addons-0.21.0 typeguard-2.13.3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
from numpy import hstack
import tensorflow as tf
from numpy import array
from datetime import datetime, timedelta
import matplotlib as mpl
from tensorflow import keras
from keras import optimizers
from keras.models import Sequential
from keras.layers import Dense, RepeatVector, TimeDistributed, Dropout, BatchNormalization, Activation
from sklearn.preprocessing import MinMaxScaler
from tcn import TCN
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
# Out:
# Matplotlib created a temporary cache directory at /var/folders/86/7gxks06s07xch2nsjg8bfzhh0000gn/T/matplotlib-fxg8kso3 because the default path (/Users/ingwerludwig/.matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %% [markdown]
# # Import Dataset

# %%
df = pd.read_excel('/Volumes/IngwerSSD/DATA/College/project-workspace/forecasting-dinas-sumber-daya air/Model Welang.xlsx','Data')
df.rename(columns={'Unnamed: 0': 'DateTime'}, inplace=True)
df['DateTime'] = pd.to_datetime(df['DateTime'])
df.sort_values(by='DateTime',ascending=True,inplace=True)
df
# Out:
#                 DateTime   RC   RL     LP     LD
# 0    2022-09-20 20:00:00  0.0  0.0  0.107  0.315
# 1    2022-09-20 21:00:00  0.0  0.0  0.108  0.307
# 2    2022-09-20 22:00:00  0.0  0.0  0.106  0.297
# 3    2022-09-20 23:00:00  0.0  0.0  0.108  0.293
# 4    2022-09-21 00:00:00  0.0  0.0  0.111  0.292
# ...                  ...  ...  ...    ...    ...
# 8611 2023-09-15 08:00:00  0.0  0.0  0.070  0.213
# 8612 2023-09-15 09:00:00  0.0  0.0  0.080  0.228
# 8613 2023-09-15 10:00:00  0.0  0.0  0.089  0.237
# 8614 2023-09-15 11:00:00  0.0  0.0  0.096  0.245
# 8615 2023-09-15 12:00:00  0.0  0.0  0.099  0.251
#
# [8616 rows x 5 columns]

# %% [markdown]
# # Isi Data yang tidak Sekuensial 1 Jam dengan Data Sebelumnya

# %%
check_df = df['DateTime']
check_df = pd.DataFrame(check_df)

check_df['TimeDifference'] = check_df['DateTime'].diff()
expected_interval = pd.to_timedelta('1 hour')
check_df['not_sequential'] = check_df['TimeDifference'] != expected_interval

check_df.at[0, 'not_sequential'] = False
filtered_df = check_df[check_df['not_sequential']]
filtered_df
# Out:
#                 DateTime  TimeDifference  not_sequential
# 14   2022-09-21 11:00:00 0 days 02:00:00            True
# 15   2022-09-21 13:00:00 0 days 02:00:00            True
# 17   2022-09-21 16:00:00 0 days 02:00:00            True
# 65   2022-09-23 17:00:00 0 days 02:00:00            True
# 1386 2022-11-17 21:00:00 0 days 04:00:00            True
# 2158 2022-12-20 04:00:00 0 days 04:00:00            True
# 4254 2023-03-17 13:00:00 0 days 02:00:00            True
# 4303 2023-03-19 17:00:00 0 days 04:00:00            True
# 4397 2023-03-23 17:00:00 0 days 03:00:00            True
# 4465 2023-03-26 14:00:00 0 days 02:00:00            True

# %%
start_date = df['DateTime'].min()
end_date = df['DateTime'].max()
date_range = pd.date_range(start=start_date, end=end_date, freq='1H')
sequence_df = pd.DataFrame({'DateTime': date_range})

df = pd.merge_asof(sequence_df, df, on='DateTime', direction='backward')

# Forward-fill missing values in the 'Akumulasi Curah Hujan Cendono' column
df['RC'].fillna(method='ffill', inplace=True)
df['RC'] = df['RC'].round(3).astype(float)

df['RL'].fillna(method='ffill', inplace=True)
df['RL'] = df['RL'].round(3).astype(float)

df['LP'].fillna(method='ffill', inplace=True)
df['LP'] = df['LP'].round(3).astype(float)

df['LD'].fillna(method='ffill', inplace=True)
df['LD'] = df['LD'].round(3).astype(float)
df
# Out:
#                 DateTime   RC   RL     LP     LD
# 0    2022-09-20 20:00:00  0.0  0.0  0.107  0.315
# 1    2022-09-20 21:00:00  0.0  0.0  0.108  0.307
# 2    2022-09-20 22:00:00  0.0  0.0  0.106  0.297
# 3    2022-09-20 23:00:00  0.0  0.0  0.108  0.293
# 4    2022-09-21 00:00:00  0.0  0.0  0.111  0.292
# ...                  ...  ...  ...    ...    ...
# 8628 2023-09-15 08:00:00  0.0  0.0  0.070  0.213
# 8629 2023-09-15 09:00:00  0.0  0.0  0.080  0.228
# 8630 2023-09-15 10:00:00  0.0  0.0  0.089  0.237
# 8631 2023-09-15 11:00:00  0.0  0.0  0.096  0.245
# 8632 2023-09-15 12:00:00  0.0  0.0  0.099  0.251
#
# [8633 rows x 5 columns]

# %%
check_df = df['DateTime']
check_df = pd.DataFrame(check_df)

check_df['TimeDifference'] = check_df['DateTime'].diff()
expected_interval = pd.to_timedelta('1 hour')
check_df['not_sequential'] = check_df['TimeDifference'] != expected_interval

# Fill the first row with False since it doesn't have a previous row for comparison
check_df.at[0, 'not_sequential'] = False
filtered_df = check_df[check_df['not_sequential']]
filtered_df
# Out:
# Empty DataFrame
# Columns: [DateTime, TimeDifference, not_sequential]
# Index: []

# %%
df.to_excel('Fix Data_Model Welang.xlsx')

# %% [markdown]
# # Load Dataset Baru

# %%
merge_df = pd.read_excel('Fix Data_Model Welang.xlsx')
merge_df.drop('Unnamed: 0',axis=1,inplace=True)
merge_df['DateTime'] = pd.to_datetime(merge_df['DateTime'])
merge_df.sort_values(by='DateTime',ascending=True,inplace=True)
merge_df
# Out:
#                 DateTime   RC   RL     LP     LD
# 0    2022-09-20 20:00:00  0.0  0.0  0.107  0.315
# 1    2022-09-20 21:00:00  0.0  0.0  0.108  0.307
# 2    2022-09-20 22:00:00  0.0  0.0  0.106  0.297
# 3    2022-09-20 23:00:00  0.0  0.0  0.108  0.293
# 4    2022-09-21 00:00:00  0.0  0.0  0.111  0.292
# ...                  ...  ...  ...    ...    ...
# 8628 2023-09-15 08:00:00  0.0  0.0  0.070  0.213
# 8629 2023-09-15 09:00:00  0.0  0.0  0.080  0.228
# 8630 2023-09-15 10:00:00  0.0  0.0  0.089  0.237
# 8631 2023-09-15 11:00:00  0.0  0.0  0.096  0.245
# 8632 2023-09-15 12:00:00  0.0  0.0  0.099  0.251
#
# [8633 rows x 5 columns]

# %%
plt.plot(merge_df['LD'])

# %% [markdown]
# # Cek data dengan nilai 0 selain di Curah Hujan

# %%
columns_to_replace = [
    'LP',
    'LD'
]

mask = (merge_df[columns_to_replace] == 0).any(axis=1)
filtered_rows = merge_df[mask]
filtered_rows.sort_values(by='DateTime')
# Out:
#                 DateTime   RC   RL   LP     LD
# 7866 2023-08-14 14:00:00  0.0  0.0  0.0  0.179
# 7884 2023-08-15 08:00:00  0.0  0.0  0.0  0.196
# 7885 2023-08-15 09:00:00  0.0  0.0  0.0  0.201
# 7886 2023-08-15 10:00:00  0.0  0.0  0.0  0.202
# 7887 2023-08-15 11:00:00  0.0  0.0  0.0  0.199
# 7888 2023-08-15 12:00:00  0.0  0.0  0.0  0.197
# 7889 2023-08-15 13:00:00  0.0  0.0  0.0  0.193
# 7890 2023-08-15 14:00:00  0.0  0.0  0.0  0.189
# 7907 2023-08-16 07:00:00  0.0  0.0  0.0  0.180
# 7908 2023-08-16 08:00:00  0.0  0.0  0.0  0.177
# 7909 2023-08-16 09:00:00  0.0  0.0  0.0  0.171
# 7910 2023-08-16 10:00:00  0.0  0.0  0.0  0.167
# 7911 2023-08-16 11:00:00  0.0  0.0  0.0  0.174
# 7912 2023-08-16 12:00:00  0.0  0.0  0.0  0.193
# 7913 2023-08-16 13:00:00  0.0  0.0  0.0  0.220
# 7914 2023-08-16 14:00:00  0.0  0.0  0.0  0.237
# 7915 2023-08-16 15:00:00  0.0  0.0  0.0  0.251
# 7931 2023-08-17 07:00:00  0.0  0.0  0.0  0.171
# 7932 2023-08-17 08:00:00  0.0  0.0  0.0  0.167
# 7933 2023-08-17 09:00:00  0.0  0.0  0.0  0.166
# 7934 2023-08-17 10:00:00  0.0  0.0  0.0  0.160
# 7935 2023-08-17 11:00:00  0.0  0.0  0.0  0.172
# 7936 2023-08-17 12:00:00  0.0  0.0  0.0  0.193
# 7937 2023-08-17 13:00:00  0.0  0.0  0.0  0.239
# 7938 2023-08-17 14:00:00  0.0  0.0  0.0  0.239
# 7939 2023-08-17 15:00:00  0.0  0.0  0.0  0.235
# 7980 2023-08-19 08:00:00  0.0  0.0  0.0  0.266
# 7981 2023-08-19 09:00:00  0.0  0.0  0.0  0.293
# 7982 2023-08-19 10:00:00  0.0  0.0  0.0  0.299
# 7983 2023-08-19 11:00:00  0.0  0.0  0.0  0.287
# 7984 2023-08-19 12:00:00  0.0  0.0  0.0  0.326
# 7985 2023-08-19 13:00:00  0.0  0.0  0.0  0.313
# 7986 2023-08-19 14:00:00  0.0  0.0  0.0  0.304
# 7987 2023-08-19 15:00:00  0.0  0.0  0.0  0.297
# 8481 2023-09-09 05:00:00  0.0  0.0  0.0  0.181

# %% [markdown]
# # Visualisasi Tren

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
copy_df_2 = merge_df.iloc[48:144,:]
copy_df_2 = copy_df_2.set_index('DateTime')
copy_df_2.index.freq = 'H'

# %%
results = seasonal_decompose(copy_df_2['LD'])
plt.figure(figsize=(42, 24))
results.plot()
plt.show()

# %% [markdown]
# # Ekstrak Fitur Datetime untuk digunakan dalam TimeSeries Forecasting

# %%
test = merge_df.iloc[0:1,0]
test
# Out:
# 0   2022-09-20 20:00:00
# Name: DateTime, dtype: datetime64[ns]

# %%
print(test.dt.hour)
# Out:
# 0    20
# Name: DateTime, dtype: int64

# %%
merge_df['hour_at'] = merge_df['DateTime'].dt.hour
merge_df
# Out:
#                 DateTime   RC   RL     LP     LD  hour_at
# 0    2022-09-20 20:00:00  0.0  0.0  0.107  0.315       20
# 1    2022-09-20 21:00:00  0.0  0.0  0.108  0.307       21
# 2    2022-09-20 22:00:00  0.0  0.0  0.106  0.297       22
# 3    2022-09-20 23:00:00  0.0  0.0  0.108  0.293       23
# 4    2022-09-21 00:00:00  0.0  0.0  0.111  0.292        0
# ...                  ...  ...  ...    ...    ...      ...
# 8628 2023-09-15 08:00:00  0.0  0.0  0.070  0.213        8
# 8629 2023-09-15 09:00:00  0.0  0.0  0.080  0.228        9
# 8630 2023-09-15 10:00:00  0.0  0.0  0.089  0.237       10
# 8631 2023-09-15 11:00:00  0.0  0.0  0.096  0.245       11
# 8632 2023-09-15 12:00:00  0.0  0.0  0.099  0.251       12
#
# [8633 rows x 6 columns]

# %% [markdown]
# # Visualisasi Jam Terhadap Rerata Muka Air Dhompo

# %%
plt.figure(figsize=(10,10))
plt.scatter(x='hour_at',y='LD',data=merge_df)
plt.xlabel('hour_at')
plt.ylabel('Rerata Tinggi Muka Air Dhompo')
# Out:
# Text(0, 0.5, 'Rerata Tinggi Muka Air Dhompo')

# %% [markdown]
# # Mutivariat Sekuens untuk Input dan Output LSTM

# %%
def split_sequences_sliding(sequences, n_steps_in, n_steps_out, step=1):
    X, y = list(), list()
    for i in range(0, len(sequences) - n_steps_in - n_steps_out + 1, step):
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out
        seq_x, seq_y = sequences[i:end_ix, :], sequences[end_ix:out_end_ix, :]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %% [markdown]
# # Train Test Split

# %%
merge_df.drop(['DateTime','hour_at'],axis=1,inplace=True)
merge_df
# Out:
#        RC   RL     LP     LD
# 0     0.0  0.0  0.107  0.315
# 1     0.0  0.0  0.108  0.307
# 2     0.0  0.0  0.106  0.297
# 3     0.0  0.0  0.108  0.293
# 4     0.0  0.0  0.111  0.292
# ...   ...  ...    ...    ...
# 8628  0.0  0.0  0.070  0.213
# 8629  0.0  0.0  0.080  0.228
# 8630  0.0  0.0  0.089  0.237
# 8631  0.0  0.0  0.096  0.245
# 8632  0.0  0.0  0.099  0.251
#
# [8633 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
train_percent = 0.7
validation_percent = 0.2

new_merge_df = merge_df
train_size = int(len(new_merge_df) * train_percent)
validation_size = int(len(new_merge_df) * validation_percent)

df_train = new_merge_df[:train_size]
df_validation = new_merge_df[train_size:(train_size + validation_size)]
df_test = new_merge_df[train_size + validation_size:]

print('Data for train:', df_train.shape)
print('Total day for train:', df_train.shape[0]/24)
print('\nData for validation:', df_validation.shape)
print('Total day for validation:', df_validation.shape[0]/24)
print('\nData for test:', df_test.shape)
print('Total day for test:', df_test.shape[0]/24)
# Out:
# Data for train: (6043, 4)
# Total day for train: 251.79166666666666
#
# Data for validation: (1726, 4)
# Total day for validation: 71.91666666666667
#
# Data for test: (864, 4)
# Total day for test: 36.0

# %%
plt.plot(df_train['LD'])

# %% [markdown]
# # Konfigurasi Multivariat Sekuens Input / Output

# %% [markdown]
# Menggunakan 6 jam sebelumnya untuk memprediksi 4 jam kedepan </br>
# Contoh sekarang jam 07.00, data 01.00 - 06.00 akan digunakan untuk memprediksi data 08.00, 09.00, 10.00

# %%
x_scaler = MinMaxScaler()
y_scaler = MinMaxScaler()

n_steps_in, n_steps_out = 5, 1

x_train, y_train = split_sequences_sliding(df_train.to_numpy(), n_steps_in, n_steps_out)
x_train = x_train.reshape(-1, 4)
y_train = y_train[:, :, -1].reshape(-1, 1)

x_scaler.fit(x_train)
y_scaler.fit(y_train)
x_train_scaled = x_scaler.transform(x_train).reshape(-1, n_steps_in, 4)
y_train_scaled = y_scaler.transform(y_train)

x_val, y_val = split_sequences_sliding(df_validation.to_numpy(), n_steps_in, n_steps_out)
x_val = x_val.reshape(-1, 4)
y_val = y_val[:, :, -1].reshape(-1, 1)
x_val_scaled = x_scaler.transform(x_val).reshape(-1, n_steps_in, 4)
y_val_scaled = y_scaler.transform(y_val)

x_test, y_test = split_sequences_sliding(df_test.to_numpy(), n_steps_in, n_steps_out)
x_test = x_test.reshape(-1, 4)
y_test = y_test[:, :, -1].reshape(-1, 1)
x_test_scaled = x_scaler.transform(x_test).reshape(-1, n_steps_in, 4)
y_test_scaled = y_scaler.transform(y_test)

n_features = x_train.shape[1]

# %%
print('Total features:', n_features)
print('Total train data:', x_train_scaled.shape)
print('Total validation data:', x_val_scaled.shape)
print('Total test data:', x_test_scaled.shape)
# Out:
# Total features: 4
# Total train data: (6038, 5, 4)
# Total validation data: (1721, 5, 4)
# Total test data: (859, 5, 4)

# %%
y_train.shape[1]
# Out:
# 1

# %% [markdown]
# # Training Model

# %%
model = Sequential()

model.add(TCN(300, input_shape=(n_steps_in, n_features)))
model.add(RepeatVector(n_steps_out))
model.add(TCN(300, return_sequences=True))
model.add(Activation('relu'))
model.add(TimeDistributed(Dense(y_train.shape[1])))

model.summary()

# %% [markdown]
# # Model Tuning

# %%
from keras import backend as K

def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %% [markdown]
# # Fit Model

# %%
epoch = 50

model.compile(optimizer='adam', loss='mae', metrics='mae')
model.fit(x_train_scaled, y_train_scaled, batch_size=1, epochs=epoch,validation_data=(x_val_scaled, y_val_scaled))
# Out:
# Epoch 1/50
# 6038/6038 [==============================] - 111s 15ms/step - loss: 0.0267 - mae: 0.0267 - val_loss: 0.0056 - val_mae: 0.0056
# Epoch 2/50
# 6038/6038 [==============================] - 95s 16ms/step - loss: 0.0153 - mae: 0.0153 - val_loss: 0.0064 - val_mae: 0.0064
# Epoch 3/50
# 6038/6038 [==============================] - 89s 15ms/step - loss: 0.0137 - mae: 0.0137 - val_loss: 0.0040 - val_mae: 0.0040
# Epoch 4/50
# 6038/6038 [==============================] - 89s 15ms/step - loss: 0.0128 - mae: 0.0128 - val_loss: 0.0064 - val_mae: 0.0064
# Epoch 5/50
# 6038/6038 [==============================] - 93s 15ms/step - loss: 0.0121 - mae: 0.0121 - val_loss: 0.0038 - val_mae: 0.0038
# Epoch 6/50
# 6038/6038 [==============================] - 92s 15ms/step - loss: 0.0119 - mae: 0.0119 - val_loss: 0.0037 - val_mae: 0.0037
# Epoch 7/50
# 6038/6038 [==============================] - 90s 15ms/step - loss: 0.0115 - mae: 0.0115 - val_loss: 0.0072 - val_mae: 0.0072
# Epoch 8/50
# 6038/6038 [==============================] - 94s 16ms/step - loss: 0.0111 - mae: 0.0111 - val_loss: 0.0061 - val_mae: 0.0061
# Epoch 9/50
# 6038/6038 [==============================] - 94s 16ms/step - loss: 0.0112 - mae: 0.0112 - val_loss: 0.0046 - val_mae: 0.0046
# Epoch 10/50
# 6038/6038 [==============================] - 89s 15ms/step - loss: 0.0110 - mae: 0.0110 - val_loss: 0.0054 - val_mae: 0.0054
# Epoch 11/50
# 6038/6038 [==============================] - 93s 15ms/step - loss: 0.0108 - mae: 0.0108 - val_loss: 0.0026 - val_mae: 0.0026
# Epoch 12/50
# 6038/6038 [==============================] - 89s 15ms/step - loss: 0.0106 - mae: 0.0106 - val_loss: 0.0030 - val_mae: 0.0030
# Epoch 13/50
# 6038/6038 [==============================] - 93s 15ms/step - loss: 0.0106 - mae: 0.0106 - val_loss: 0.0052 - val_mae: 0.0052
# Epoch 14/50
# 6038/6038 [==============================] - 89s 15ms/step - loss: 0.0105 - mae: 0.0105 - val_loss: 0.0079 - val_mae: 0.0079
# Epoch 15/50
# 6038/6038 [==============================] - 94s 16ms/step - loss: 0.0105 - mae: 0.0105 - val_loss: 0.0031 - val_mae: 0.0031
# Epoch 16/50
# 6038/6038 [==============================] - 91s 15ms/step - loss: 0.0104 - mae: 0.0104 - val_loss: 0.0036 - val_mae: 0.0036
# Epoch 17/50
# 6038/6038 [==============================] - 90s 15ms/step - loss: 0.0104 - mae: 0.0104 - val_loss: 0.0058 - val_mae: 0.0058
# Epoch 18/50
# 6038/6038 [==============================] - 94s 16ms/step - loss: 0.0102 - mae: 0.0102 - val_loss: 0.0038 - val_mae: 0.0038
# Epoch 19/50
# 6038/6038 [==============================] - 94s 16ms/step - loss: 0.0102 - mae: 0.0102 - val_loss: 0.0026 - val_mae: 0.0026
# Epoch 20/50
# 6038/6038 [==============================] - 89s 15ms/step - loss: 0.0101 - mae: 0.0101 - val_loss: 0.0082 - val_mae: 0.0082
# Epoch 21/50
# 6038/6038 [==============================] - 94s 15ms/step - loss: 0.0102 - mae: 0.0102 - val_loss: 0.0033 - val_mae: 0.0033
# Epoch 22/50
# 6038/6038 [==============================] - 90s 15ms/step - loss: 0.0101 - mae: 0.0101 - val_loss: 0.0027 - val_mae: 0.0027
# Epoch 23/50
# 6038/6038 [==============================] - 90s 15ms/step - loss: 0.0101 - mae: 0.0101 - val_loss: 0.0033 - val_mae: 0.0033
# Epoch 24/50
# 6038/6038 [==============================] - 94s 16ms/step - loss: 0.0101 - mae: 0.0101 - val_loss: 0.0052 - val_mae: 0.0052
# Epoch 25/50
# 6038/6038 [==============================] - 95s 16ms/step - loss: 0.0100 - mae: 0.0100 - val_loss: 0.0034 - val_mae: 0.0034
# Epoch 26/50
# 6038/6038 [==============================] - 90s 15ms/step - loss: 0.0101 - mae: 0.0101 - val_loss: 0.0044 - val_mae: 0.0044
# Epoch 27/50
# 6038/6038 [==============================] - 90s 15ms/step - loss: 0.0103 - mae: 0.0103 - val_loss: 0.0044 - val_mae: 0.0044
# Epoch 28/50
# 6038/6038 [==============================] - 94s 16ms/step - loss: 0.0100 - mae: 0.0100 - val_loss: 0.0034 - val_mae: 0.0034
# Epoch 29/50
# 6038/6038 [==============================] - 94s 16ms/step - loss: 0.0099 - mae: 0.0099 - val_loss: 0.0036 - val_mae: 0.0036
# Epoch 30/50
# 6038/6038 [==============================] - 91s 15ms/step - loss: 0.0097 - mae: 0.0097 - val_loss: 0.0033 - val_mae: 0.0033
# Epoch 31/50
# 6038/6038 [==============================] - 90s 15ms/step - loss: 0.0098 - mae: 0.0098 - val_loss: 0.0034 - val_mae: 0.0034
# Epoch 32/50
# 6038/6038 [==============================] - 95s 16ms/step - loss: 0.0096 - mae: 0.0096 - val_loss: 0.0042 - val_mae: 0.0042
# Epoch 33/50
# 6038/6038 [==============================] - 95s 16ms/step - loss: 0.0098 - mae: 0.0098 - val_loss: 0.0069 - val_mae: 0.0069
# Epoch 34/50
# 6038/6038 [==============================] - 91s 15ms/step - loss: 0.0098 - mae: 0.0098 - val_loss: 0.0026 - val_mae: 0.0026
# Epoch 35/50
# 6038/6038 [==============================] - 91s 15ms/step - loss: 0.0097 - mae: 0.0097 - val_loss: 0.0030 - val_mae: 0.0030
# Epoch 36/50
# 6038/6038 [==============================] - 92s 15ms/step - loss: 0.0096 - mae: 0.0096 - val_loss: 0.0033 - val_mae: 0.0033
# Epoch 37/50
# 6038/6038 [==============================] - 95s 16ms/step - loss: 0.0097 - mae: 0.0097 - val_loss: 0.0032 - val_mae: 0.0032
# Epoch 38/50
# 6038/6038 [==============================] - 91s 15ms/step - loss: 0.0096 - mae: 0.0096 - val_loss: 0.0041 - val_mae: 0.0041
# Epoch 39/50
# 6038/6038 [==============================] - 87s 14ms/step - loss: 0.0096 - mae: 0.0096 - val_loss: 0.0031 - val_mae: 0.0031
# Epoch 40/50
# 6038/6038 [==============================] - 86s 14ms/step - loss: 0.0097 - mae: 0.0097 - val_loss: 0.0069 - val_mae: 0.0069
# Epoch 41/50
# 6038/6038 [==============================] - 86s 14ms/step - loss: 0.0097 - mae: 0.0097 - val_loss: 0.0040 - val_mae: 0.0040
# Epoch 42/50
# 6038/6038 [==============================] - 90s 15ms/step - loss: 0.0096 - mae: 0.0096 - val_loss: 0.0046 - val_mae: 0.0046
# Epoch 43/50
# 6038/6038 [==============================] - 89s 15ms/step - loss: 0.0097 - mae: 0.0097 - val_loss: 0.0037 - val_mae: 0.0037
# Epoch 44/50
# 6038/6038 [==============================] - 84s 14ms/step - loss: 0.0097 - mae: 0.0097 - val_loss: 0.0040 - val_mae: 0.0040
# Epoch 45/50
# 6038/6038 [==============================] - 88s 15ms/step - loss: 0.0096 - mae: 0.0096 - val_loss: 0.0052 - val_mae: 0.0052
# Epoch 46/50
# 6038/6038 [==============================] - 88s 15ms/step - loss: 0.0096 - mae: 0.0096 - val_loss: 0.0028 - val_mae: 0.0028
# Epoch 47/50
# 6038/6038 [==============================] - 84s 14ms/step - loss: 0.0095 - mae: 0.0095 - val_loss: 0.0030 - val_mae: 0.0030
# Epoch 48/50
# 6038/6038 [==============================] - 85s 14ms/step - loss: 0.0097 - mae: 0.0097 - val_loss: 0.0050 - val_mae: 0.0050
# Epoch 49/50
# 6038/6038 [==============================] - 88s 15ms/step - loss: 0.0097 - mae: 0.0097 - val_loss: 0.0033 - val_mae: 0.0033
# Epoch 50/50
# 6038/6038 [==============================] - 91s 15ms/step - loss: 0.0095 - mae: 0.0095 - val_loss: 0.0050 - val_mae: 0.0050

# %% [markdown]
# # Test Model

# %%
predictions = y_scaler.inverse_transform(model.predict_generator(x_test_scaled).reshape(-1,1))
print(predictions.shape)
print(y_test.shape)
# Out:
# (859, 1)
# (859, 1)

# %%
predictions_train = y_scaler.inverse_transform(model.predict_generator(x_train_scaled).reshape(-1,1))
print(predictions_train.shape)
print(y_train.shape)
# Out:
# (6038, 1)
# (6038, 1)

# %% [markdown]
# # Bentuk Prediksi ke Dataframe

# %%
real = y_test
real_train = y_train

# rescale predictions
predictions = pd.DataFrame(predictions)
predictions = predictions
predictions = pd.DataFrame(predictions)

predictions_for_train = pd.DataFrame(predictions_train)
predictions_for_train = predictions_train
predictions_for_train = pd.DataFrame(predictions_train)

real = pd.DataFrame(real)
real = real
real = pd.DataFrame(real)

real_train = pd.DataFrame(real_train)
real_train =real_train
real_train = pd.DataFrame(real_train)

print(predictions.shape)
print(real.shape)

print(predictions_for_train.shape)
print(real_train.shape)
# Out:
# (859, 1)
# (859, 1)
# (6038, 1)
# (6038, 1)

# %%
df_final = pd.DataFrame()
df_final_train = pd.DataFrame()

# %%
df_final['Tinggi Muka Air Dhompo'] = real[0]
df_final['Prediksi Tinggi Muka Air Dhompo'] = predictions[0]

# %%
df_final_train['Tinggi Muka Air Dhompo'] = real_train[0]
df_final_train['Prediksi Tinggi Muka Air Dhompo'] = predictions_for_train[0]

# %% [markdown]
# # Plot Model Test Dataset

# %%
mpl.rcParams['figure.figsize'] = (20,10)
mpl.rcParams['axes.grid'] = False
df_final[['Tinggi Muka Air Dhompo', 'Prediksi Tinggi Muka Air Dhompo']].plot()
# Out:
# <Axes: >

# %% [markdown]
# # Plot Model Train Dataset

# %%
mpl.rcParams['figure.figsize'] = (20,10)
mpl.rcParams['axes.grid'] = False
df_final_train[['Tinggi Muka Air Dhompo', 'Prediksi Tinggi Muka Air Dhompo']].plot()
# Out:
# <Axes: >

# %% [markdown]
# # Evaluation Score

# %%
rmse_scores = []
model_names = []
mse_scores = []
mape_scores = []
mae_scores = []

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_percentage_error

indicator = [ 'Tinggi Muka Air Dhompo']

for i in indicator:
  rmse_scores.append(mean_squared_error(df_final[f'{i}'],df_final[f'Prediksi {i}'], squared=False))
  mse_scores.append(mean_squared_error(df_final[f'{i}'],df_final[f'Prediksi {i}']))
  mae_scores.append(mean_absolute_error(df_final[f'{i}'], df_final[f'Prediksi {i}']))
  mape_scores.append(mean_absolute_percentage_error(df_final[f'{i}'], df_final[f'Prediksi {i}']))
  model_names.append(i)

# %%
data = {'Fitur Yang Akan Diprediksi': model_names, 'RMSE Score Prediction': rmse_scores, 'MSE Score Prediction': mse_scores,'MAE Score Prediction': mae_scores, 'MAPE Score Prediction' : mape_scores}
df_evaluation = pd.DataFrame(data)
df_evaluation = df_evaluation.sort_values(by='RMSE Score Prediction', ascending=True)
pd.set_option('display.float_format', '{:.2f}'.format)
df_evaluation
# Out:
#   Fitur Yang Akan Diprediksi  RMSE Score Prediction  MSE Score Prediction  \
# 0     Tinggi Muka Air Dhompo                   0.02                  0.00
#
#    MAE Score Prediction  MAPE Score Prediction
# 0                  0.01                   0.07

# %%
df_evaluation.to_excel('TCN_result.xlsx')

# %% [markdown]
# # Perbandingan Selisih Dalam Angka

# %%
df_final = df_final.round(2)

df_final['Difference_Rerata'] = abs(df_final['Tinggi Muka Air Dhompo'] - df_final['Prediksi Tinggi Muka Air Dhompo'])
df_final
# Out:
#      Tinggi Muka Air Dhompo  Prediksi Tinggi Muka Air Dhompo  \
# 0                      0.12                             0.14
# 1                      0.13                             0.13
# 2                      0.17                             0.14
# 3                      0.19                             0.17
# 4                      0.21                             0.19
# ..                      ...                              ...
# 854                    0.21                             0.19
# 855                    0.23                             0.20
# 856                    0.24                             0.21
# 857                    0.24                             0.22
# 858                    0.25                             0.22
#
#      Difference_Rerata
# 0                 0.02
# 1                 0.00
# 2                 0.03
# 3                 0.02
# 4                 0.02
# ..                 ...
# 854               0.02
# 855               0.03
# 856               0.03
# 857               0.02
# 858               0.03
#
# [859 rows x 3 columns]

# %%
test = df_final.sort_values(by='Difference_Rerata', ascending=False)
test[test['Difference_Rerata']>0.10].head(20)
# Out:
#      Tinggi Muka Air Dhompo  Prediksi Tinggi Muka Air Dhompo  \
# 294                    0.31                             0.17
#
#      Difference_Rerata
# 294               0.14

# %% [markdown]
# # Save Model

# %%
model.save_weights('./checkpoints/my_checkpoint')

# %%
# !mkdir -p saved_model
model.save('saved_model/muka_air_dhompo/tcn-ffws-model-batch-1-300-5-hari')
model.save('muka_air_dhompo_tcn-ffws-model-batch-1-300-neuron-5-hari.h5')

# %%
import zipfile
import os

def zip_folder(folder_path, output_zip_path):
  """Zips a folder into a ZIP file.

  Args:
    folder_path: The path to the folder to be zipped.
    output_zip_path: The path to the output ZIP file.
  """

  with zipfile.ZipFile(output_zip_path, 'w') as zip_file:
    for root, dirs, files in os.walk(folder_path):
      for file in files:
        zip_file.write(os.path.join(root, file))

# Zip the folder '/content/my_folder' into the ZIP file '/content/my_folder.zip'
zip_folder('/content/saved_model', '/content/saved_model.zip')

# %%
zip_folder('/content/saved_model', '/content/saved_model.zip')

# %%
import pickle
with open('dhompo_tcn_x_scaler.pkl', 'wb') as file:
    pickle.dump(x_scaler, file)
    
with open('dhompo_tcn_y_scaler.pkl', 'wb') as file:
    pickle.dump(y_scaler, file)
