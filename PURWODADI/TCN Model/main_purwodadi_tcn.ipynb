# %% [markdown]
# # Import Dependensi

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
from numpy import hstack
import tensorflow as tf
from numpy import array
from datetime import datetime, timedelta
import matplotlib as mpl
from tensorflow import keras
from keras import optimizers
from keras.models import Sequential
from keras.layers import Dense, RepeatVector, TimeDistributed, Dropout, BatchNormalization, Activation
from tcn import TCN
from sklearn.preprocessing import MinMaxScaler
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
# Out:
# Matplotlib created a temporary cache directory at /var/folders/86/7gxks06s07xch2nsjg8bfzhh0000gn/T/matplotlib-mbywb4lg because the default path (/Users/ingwerludwig/.matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %% [markdown]
# # Load Dataset Baru

# %%
import os
parent_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir, os.pardir))
excel_path = os.path.join(parent_dir, 'Fix Data_Model Welang.xlsx')

# %%
merge_df = pd.read_excel(excel_path)
merge_df.drop('Unnamed: 0',axis=1,inplace=True)
merge_df['DateTime'] = pd.to_datetime(merge_df['DateTime'])
merge_df.sort_values(by='DateTime',ascending=True,inplace=True)
merge_df
# Out:
#                 DateTime   RC   RL     LP     LD
# 0    2022-09-20 20:00:00  0.0  0.0  0.107  0.315
# 1    2022-09-20 21:00:00  0.0  0.0  0.108  0.307
# 2    2022-09-20 22:00:00  0.0  0.0  0.106  0.297
# 3    2022-09-20 23:00:00  0.0  0.0  0.108  0.293
# 4    2022-09-21 00:00:00  0.0  0.0  0.111  0.292
# ...                  ...  ...  ...    ...    ...
# 8628 2023-09-15 08:00:00  0.0  0.0  0.070  0.213
# 8629 2023-09-15 09:00:00  0.0  0.0  0.080  0.228
# 8630 2023-09-15 10:00:00  0.0  0.0  0.089  0.237
# 8631 2023-09-15 11:00:00  0.0  0.0  0.096  0.245
# 8632 2023-09-15 12:00:00  0.0  0.0  0.099  0.251
#
# [8633 rows x 5 columns]

# %%
plt.figure(figsize=(30, 15))
plt.plot(merge_df['LP'])

# %% [markdown]
# # Cek data dengan nilai 0 selain di Curah Hujan

# %%
columns_to_replace = [
    'LP',
    'LD'
]

mask = (merge_df[columns_to_replace] == 0).any(axis=1)
filtered_rows = merge_df[mask]
filtered_rows.sort_values(by='DateTime')
# Out:
#                 DateTime   RC   RL   LP     LD
# 7866 2023-08-14 14:00:00  0.0  0.0  0.0  0.179
# 7884 2023-08-15 08:00:00  0.0  0.0  0.0  0.196
# 7885 2023-08-15 09:00:00  0.0  0.0  0.0  0.201
# 7886 2023-08-15 10:00:00  0.0  0.0  0.0  0.202
# 7887 2023-08-15 11:00:00  0.0  0.0  0.0  0.199
# 7888 2023-08-15 12:00:00  0.0  0.0  0.0  0.197
# 7889 2023-08-15 13:00:00  0.0  0.0  0.0  0.193
# 7890 2023-08-15 14:00:00  0.0  0.0  0.0  0.189
# 7907 2023-08-16 07:00:00  0.0  0.0  0.0  0.180
# 7908 2023-08-16 08:00:00  0.0  0.0  0.0  0.177
# 7909 2023-08-16 09:00:00  0.0  0.0  0.0  0.171
# 7910 2023-08-16 10:00:00  0.0  0.0  0.0  0.167
# 7911 2023-08-16 11:00:00  0.0  0.0  0.0  0.174
# 7912 2023-08-16 12:00:00  0.0  0.0  0.0  0.193
# 7913 2023-08-16 13:00:00  0.0  0.0  0.0  0.220
# 7914 2023-08-16 14:00:00  0.0  0.0  0.0  0.237
# 7915 2023-08-16 15:00:00  0.0  0.0  0.0  0.251
# 7931 2023-08-17 07:00:00  0.0  0.0  0.0  0.171
# 7932 2023-08-17 08:00:00  0.0  0.0  0.0  0.167
# 7933 2023-08-17 09:00:00  0.0  0.0  0.0  0.166
# 7934 2023-08-17 10:00:00  0.0  0.0  0.0  0.160
# 7935 2023-08-17 11:00:00  0.0  0.0  0.0  0.172
# 7936 2023-08-17 12:00:00  0.0  0.0  0.0  0.193
# 7937 2023-08-17 13:00:00  0.0  0.0  0.0  0.239
# 7938 2023-08-17 14:00:00  0.0  0.0  0.0  0.239
# 7939 2023-08-17 15:00:00  0.0  0.0  0.0  0.235
# 7980 2023-08-19 08:00:00  0.0  0.0  0.0  0.266
# 7981 2023-08-19 09:00:00  0.0  0.0  0.0  0.293
# 7982 2023-08-19 10:00:00  0.0  0.0  0.0  0.299
# 7983 2023-08-19 11:00:00  0.0  0.0  0.0  0.287
# 7984 2023-08-19 12:00:00  0.0  0.0  0.0  0.326
# 7985 2023-08-19 13:00:00  0.0  0.0  0.0  0.313
# 7986 2023-08-19 14:00:00  0.0  0.0  0.0  0.304
# 7987 2023-08-19 15:00:00  0.0  0.0  0.0  0.297
# 8481 2023-09-09 05:00:00  0.0  0.0  0.0  0.181

# %% [markdown]
# # Visualisasi Tren

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
copy_df_2 = merge_df.iloc[48:144,:]
copy_df_2 = copy_df_2.set_index('DateTime')
copy_df_2.index.freq = 'H'

# %%
results = seasonal_decompose(copy_df_2['LP'])

plt.figure(figsize=(12, 8))

plt.subplot(411)
plt.plot(copy_df_2['LP'], label='Original')
plt.legend()

plt.subplot(412)
plt.plot(results.trend, label='Trend')
plt.legend()

plt.subplot(413)
plt.plot(results.seasonal, label='Seasonal')
plt.legend()

plt.subplot(414)
plt.plot(results.resid, label='Residual')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Ekstrak Fitur Datetime untuk digunakan dalam TimeSeries Forecasting

# %%
test = merge_df.iloc[0:1,0]
test
# Out:
# 0   2022-09-20 20:00:00
# Name: DateTime, dtype: datetime64[ns]

# %%
print(test.dt.hour)
# Out:
# 0    20
# Name: DateTime, dtype: int32

# %%
merge_df['hour_at'] = merge_df['DateTime'].dt.hour
merge_df
# Out:
#                 DateTime   RC   RL     LP     LD  hour_at
# 0    2022-09-20 20:00:00  0.0  0.0  0.107  0.315       20
# 1    2022-09-20 21:00:00  0.0  0.0  0.108  0.307       21
# 2    2022-09-20 22:00:00  0.0  0.0  0.106  0.297       22
# 3    2022-09-20 23:00:00  0.0  0.0  0.108  0.293       23
# 4    2022-09-21 00:00:00  0.0  0.0  0.111  0.292        0
# ...                  ...  ...  ...    ...    ...      ...
# 8628 2023-09-15 08:00:00  0.0  0.0  0.070  0.213        8
# 8629 2023-09-15 09:00:00  0.0  0.0  0.080  0.228        9
# 8630 2023-09-15 10:00:00  0.0  0.0  0.089  0.237       10
# 8631 2023-09-15 11:00:00  0.0  0.0  0.096  0.245       11
# 8632 2023-09-15 12:00:00  0.0  0.0  0.099  0.251       12
#
# [8633 rows x 6 columns]

# %% [markdown]
# # Visualisasi Jam Terhadap Rerata Muka Air Purwodadi

# %%
plt.figure(figsize=(10,10))
plt.scatter(x='hour_at',y='LP',data=merge_df)
plt.xlabel('hour_at')
plt.ylabel('Rerata Tinggi Muka Air Purwodadi')
# Out:
# Text(0, 0.5, 'Rerata Tinggi Muka Air Purwodadi')

# %% [markdown]
# # Mutivariat Sekuens untuk Input dan Output LSTM

# %%
def split_sequences_sliding(sequences, n_steps_in, n_steps_out, step=1):
    X, y = list(), list()
    for i in range(0, len(sequences) - n_steps_in - n_steps_out + 1, step):
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out
        seq_x, seq_y = sequences[i:end_ix, :], sequences[end_ix:out_end_ix, :]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %%
merge_df.drop(['DateTime','hour_at','LD'],axis=1,inplace=True)
merge_df
# Out:
#        RC   RL     LP
# 0     0.0  0.0  0.107
# 1     0.0  0.0  0.108
# 2     0.0  0.0  0.106
# 3     0.0  0.0  0.108
# 4     0.0  0.0  0.111
# ...   ...  ...    ...
# 8628  0.0  0.0  0.070
# 8629  0.0  0.0  0.080
# 8630  0.0  0.0  0.089
# 8631  0.0  0.0  0.096
# 8632  0.0  0.0  0.099
#
# [8633 rows x 3 columns]

# %% [markdown]
# # Apply Sliding Window

# %%
n_steps_in, n_steps_out = 3, 3
train_percent, validation_percent = 0.7, 0.2

x_data, y_data = split_sequences_sliding(merge_df.to_numpy(), n_steps_in, n_steps_out)

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
x_for_training_and_val, x_test, y_for_training_and_val, y_test = train_test_split(x_data, y_data, test_size=1-train_percent-validation_percent)
x_train, x_validation, y_train, y_validation = train_test_split(x_for_training_and_val, y_for_training_and_val, test_size=0.23)

# %%
y_test = y_test[:, :, -1].reshape(-1, n_steps_out)
y_train = y_train[:, :, -1].reshape(-1, n_steps_out)
y_validation = y_validation[:, :, -1].reshape(-1, n_steps_out)

# %%
print('Data for train:', x_train.shape, y_train.shape)
print('Total days for train:', x_train.shape[0] / 24)
print('\nData for validation:', x_validation.shape, y_validation.shape)
print('Total days for validation:', x_validation.shape[0]  / 24)
print('\nData for test:', x_test.shape, y_test.shape)
print('Total days for test:', x_test.shape[0]  / 24)
# Out:
# Data for train: (5979, 3, 3) (5979, 3)
# Total days for train: 249.125
#
# Data for validation: (1786, 3, 3) (1786, 3)
# Total days for validation: 74.41666666666667
#
# Data for test: (863, 3, 3) (863, 3)
# Total days for test: 35.958333333333336

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler

x_train_reshaped = x_train.reshape(-1, x_train.shape[-1])
x_validation_reshaped = x_validation.reshape(-1, x_validation.shape[-1])
x_test_reshaped = x_test.reshape(-1, x_test.shape[-1])

x_scaler = StandardScaler()
x_scaler.fit(x_train_reshaped)

x_train_scaled = x_scaler.transform(x_train_reshaped).reshape(x_train.shape)
x_validation_scaled = x_scaler.transform(x_validation_reshaped).reshape(x_validation.shape)
x_test_scaled = x_scaler.transform(x_test_reshaped).reshape(x_test.shape)

y_train_reshaped = y_train
y_validation_reshaped = y_validation
y_test_reshaped = y_test

y_scaler = StandardScaler()
y_scaler.fit(y_train_reshaped)

y_train_scaled = y_scaler.transform(y_train_reshaped)
y_validation_scaled = y_scaler.transform(y_validation_reshaped)
y_test_scaled = y_scaler.transform(y_test_reshaped)

# %%
print('Data for train:', x_train_scaled.shape, y_train_scaled.shape)
print('Total days for train:', x_train_scaled.shape[0] / 24)
print('\nData for validation:', x_validation_scaled.shape, y_validation_scaled.shape)
print('Total days for validation:', x_validation_scaled.shape[0] / 24)
print('\nData for test:', x_test_scaled.shape, y_test_scaled.shape)
print('Total days for test:', x_test_scaled.shape[0] / 24)
# Out:
# Data for train: (5979, 3, 3) (5979, 3)
# Total days for train: 249.125
#
# Data for validation: (1786, 3, 3) (1786, 3)
# Total days for validation: 74.41666666666667
#
# Data for test: (863, 3, 3) (863, 3)
# Total days for test: 35.958333333333336

# %%
print('Total features:', 3)
print('Total train data:', x_train_scaled.shape)
print('Total validation data:', x_validation_scaled.shape)
print('Total test data:', x_test_scaled.shape)
# Out:
# Total features: 3
# Total train data: (5979, 3, 3)
# Total validation data: (1786, 3, 3)
# Total test data: (863, 3, 3)

# %%
print('Total features:', 3)
print('Total train data:', y_train_scaled.shape)
print('Total validation data:', y_validation_scaled.shape)
print('Total test data:', y_test_scaled.shape)
# Out:
# Total features: 3
# Total train data: (5979, 3)
# Total validation data: (1786, 3)
# Total test data: (863, 3)

# %% [markdown]
# # Training Model

# %%
model = Sequential()

model.add(TCN(300, input_shape=(n_steps_in, 3)))
model.add(RepeatVector(n_steps_out))
model.add(TCN(300, return_sequences=True))
model.add(Activation('relu'))
model.add(TimeDistributed(Dense(1)))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tcn (TCN)                   (None, 300)               2977500
#
#  repeat_vector (RepeatVecto  (None, 3, 300)            0
#  r)
#
#  tcn_1 (TCN)                 (None, 3, 300)            3243600
#
#  activation (Activation)     (None, 3, 300)            0
#
#  time_distributed (TimeDist  (None, 3, 1)              301
#  ributed)
#
# =================================================================
# Total params: 6221401 (23.73 MB)
# Trainable params: 6221401 (23.73 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Model Tuning

# %%
from keras import backend as K

def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %% [markdown]
# # Fit Model

# %%
import tensorflow as tf
from tf.keras.metrics import RootMeanSquaredError

# %%
epoch = 50
model.compile(optimizer='adam', loss=root_mean_squared_error, metrics=root_mean_squared_error)
model.fit(x_train_scaled, y_train_scaled, epochs=epoch, batch_size=32,validation_data=(x_validation_scaled, y_validation_scaled), verbose=1)
# Out:
# Epoch 1/50
# 187/187 [==============================] - 30s 153ms/step - loss: 1.5646 - root_mean_squared_error: 1.5636 - val_loss: 0.4554 - val_root_mean_squared_error: 0.4544
# Epoch 2/50
# 187/187 [==============================] - 26s 139ms/step - loss: 0.5297 - root_mean_squared_error: 0.5295 - val_loss: 0.4818 - val_root_mean_squared_error: 0.4808
# Epoch 3/50
# 187/187 [==============================] - 27s 146ms/step - loss: 0.5166 - root_mean_squared_error: 0.5164 - val_loss: 0.4487 - val_root_mean_squared_error: 0.4478
# Epoch 4/50
# 187/187 [==============================] - 28s 150ms/step - loss: 0.4835 - root_mean_squared_error: 0.4832 - val_loss: 0.4908 - val_root_mean_squared_error: 0.4896
# Epoch 5/50
# 187/187 [==============================] - 29s 154ms/step - loss: 0.4714 - root_mean_squared_error: 0.4714 - val_loss: 0.4515 - val_root_mean_squared_error: 0.4506
# Epoch 6/50
# 187/187 [==============================] - 29s 156ms/step - loss: 0.4922 - root_mean_squared_error: 0.4919 - val_loss: 0.4321 - val_root_mean_squared_error: 0.4311
# Epoch 7/50
# 187/187 [==============================] - 31s 168ms/step - loss: 0.4708 - root_mean_squared_error: 0.4706 - val_loss: 0.4404 - val_root_mean_squared_error: 0.4395
# Epoch 8/50
# 187/187 [==============================] - 40s 214ms/step - loss: 0.4690 - root_mean_squared_error: 0.4694 - val_loss: 0.4284 - val_root_mean_squared_error: 0.4274
# Epoch 9/50
# 187/187 [==============================] - 32s 171ms/step - loss: 0.4778 - root_mean_squared_error: 0.4777 - val_loss: 0.4296 - val_root_mean_squared_error: 0.4287
# Epoch 10/50
# 187/187 [==============================] - 32s 173ms/step - loss: 0.4729 - root_mean_squared_error: 0.4726 - val_loss: 0.4337 - val_root_mean_squared_error: 0.4328
# Epoch 11/50
# 187/187 [==============================] - 35s 189ms/step - loss: 0.4721 - root_mean_squared_error: 0.4720 - val_loss: 0.4267 - val_root_mean_squared_error: 0.4258
# Epoch 12/50
# 187/187 [==============================] - 31s 163ms/step - loss: 0.4675 - root_mean_squared_error: 0.4673 - val_loss: 0.4344 - val_root_mean_squared_error: 0.4335
# Epoch 13/50
# 187/187 [==============================] - 30s 163ms/step - loss: 0.4723 - root_mean_squared_error: 0.4722 - val_loss: 0.4604 - val_root_mean_squared_error: 0.4595
# Epoch 14/50
# 187/187 [==============================] - 31s 164ms/step - loss: 0.4768 - root_mean_squared_error: 0.4767 - val_loss: 0.4417 - val_root_mean_squared_error: 0.4407
# Epoch 15/50
# 187/187 [==============================] - 31s 167ms/step - loss: 0.4484 - root_mean_squared_error: 0.4482 - val_loss: 0.4180 - val_root_mean_squared_error: 0.4171
# Epoch 16/50
# 187/187 [==============================] - 33s 176ms/step - loss: 0.4457 - root_mean_squared_error: 0.4454 - val_loss: 0.4294 - val_root_mean_squared_error: 0.4285
# Epoch 17/50
# 187/187 [==============================] - 30s 161ms/step - loss: 0.4558 - root_mean_squared_error: 0.4558 - val_loss: 0.4250 - val_root_mean_squared_error: 0.4241
# Epoch 18/50
# 187/187 [==============================] - 30s 163ms/step - loss: 0.4519 - root_mean_squared_error: 0.4518 - val_loss: 0.4579 - val_root_mean_squared_error: 0.4569
# Epoch 19/50
# 187/187 [==============================] - 31s 166ms/step - loss: 0.4537 - root_mean_squared_error: 0.4535 - val_loss: 0.4461 - val_root_mean_squared_error: 0.4451
# Epoch 20/50
# 187/187 [==============================] - 30s 162ms/step - loss: 0.4568 - root_mean_squared_error: 0.4569 - val_loss: 0.4221 - val_root_mean_squared_error: 0.4212
# Epoch 21/50
# 187/187 [==============================] - 31s 164ms/step - loss: 0.4509 - root_mean_squared_error: 0.4507 - val_loss: 0.4665 - val_root_mean_squared_error: 0.4655
# Epoch 22/50
# 187/187 [==============================] - 31s 164ms/step - loss: 0.4661 - root_mean_squared_error: 0.4660 - val_loss: 0.4322 - val_root_mean_squared_error: 0.4313
# Epoch 23/50
# 187/187 [==============================] - 30s 162ms/step - loss: 0.4390 - root_mean_squared_error: 0.4390 - val_loss: 0.4198 - val_root_mean_squared_error: 0.4188
# Epoch 24/50
# 187/187 [==============================] - 30s 163ms/step - loss: 0.4518 - root_mean_squared_error: 0.4515 - val_loss: 0.4313 - val_root_mean_squared_error: 0.4303
# Epoch 25/50
# 187/187 [==============================] - 31s 165ms/step - loss: 0.4546 - root_mean_squared_error: 0.4547 - val_loss: 0.4153 - val_root_mean_squared_error: 0.4145
# Epoch 26/50
# 187/187 [==============================] - 31s 165ms/step - loss: 0.4440 - root_mean_squared_error: 0.4437 - val_loss: 0.4200 - val_root_mean_squared_error: 0.4191
# Epoch 27/50
# 187/187 [==============================] - 31s 165ms/step - loss: 0.4539 - root_mean_squared_error: 0.4538 - val_loss: 0.4459 - val_root_mean_squared_error: 0.4451
# Epoch 28/50
# 187/187 [==============================] - 31s 165ms/step - loss: 0.4479 - root_mean_squared_error: 0.4479 - val_loss: 0.4237 - val_root_mean_squared_error: 0.4227
# Epoch 29/50
# 187/187 [==============================] - 31s 166ms/step - loss: 0.4435 - root_mean_squared_error: 0.4433 - val_loss: 0.4227 - val_root_mean_squared_error: 0.4218
# Epoch 30/50
# 187/187 [==============================] - 32s 170ms/step - loss: 0.4492 - root_mean_squared_error: 0.4490 - val_loss: 0.4232 - val_root_mean_squared_error: 0.4223
# Epoch 31/50
# 187/187 [==============================] - 32s 171ms/step - loss: 0.4363 - root_mean_squared_error: 0.4361 - val_loss: 0.4233 - val_root_mean_squared_error: 0.4224
# Epoch 32/50
# 187/187 [==============================] - 33s 175ms/step - loss: 0.4268 - root_mean_squared_error: 0.4267 - val_loss: 0.4210 - val_root_mean_squared_error: 0.4200
# Epoch 33/50
# 187/187 [==============================] - 33s 178ms/step - loss: 0.4324 - root_mean_squared_error: 0.4321 - val_loss: 0.4216 - val_root_mean_squared_error: 0.4208
# Epoch 34/50
# 187/187 [==============================] - 33s 178ms/step - loss: 0.4396 - root_mean_squared_error: 0.4394 - val_loss: 0.4193 - val_root_mean_squared_error: 0.4184
# Epoch 35/50
# 187/187 [==============================] - 35s 185ms/step - loss: 0.4405 - root_mean_squared_error: 0.4406 - val_loss: 0.4219 - val_root_mean_squared_error: 0.4210
# Epoch 36/50
# 187/187 [==============================] - 33s 179ms/step - loss: 0.4350 - root_mean_squared_error: 0.4348 - val_loss: 0.4571 - val_root_mean_squared_error: 0.4562
# Epoch 37/50
# 187/187 [==============================] - 33s 179ms/step - loss: 0.4466 - root_mean_squared_error: 0.4467 - val_loss: 0.4183 - val_root_mean_squared_error: 0.4174
# Epoch 38/50
# 187/187 [==============================] - 38s 203ms/step - loss: 0.4277 - root_mean_squared_error: 0.4279 - val_loss: 0.4281 - val_root_mean_squared_error: 0.4271
# Epoch 39/50
# 187/187 [==============================] - 37s 197ms/step - loss: 0.4359 - root_mean_squared_error: 0.4359 - val_loss: 0.4207 - val_root_mean_squared_error: 0.4198
# Epoch 40/50
# 187/187 [==============================] - 45s 243ms/step - loss: 0.4336 - root_mean_squared_error: 0.4334 - val_loss: 0.4196 - val_root_mean_squared_error: 0.4188
# Epoch 41/50
# 187/187 [==============================] - 42s 226ms/step - loss: 0.4375 - root_mean_squared_error: 0.4372 - val_loss: 0.4159 - val_root_mean_squared_error: 0.4150
# Epoch 42/50
# 187/187 [==============================] - 42s 223ms/step - loss: 0.4257 - root_mean_squared_error: 0.4256 - val_loss: 0.4195 - val_root_mean_squared_error: 0.4186
# Epoch 43/50
# 187/187 [==============================] - 42s 223ms/step - loss: 0.4328 - root_mean_squared_error: 0.4325 - val_loss: 0.4194 - val_root_mean_squared_error: 0.4185
# Epoch 44/50
# 187/187 [==============================] - 44s 234ms/step - loss: 0.4286 - root_mean_squared_error: 0.4284 - val_loss: 0.4274 - val_root_mean_squared_error: 0.4265
# Epoch 45/50
# 187/187 [==============================] - 44s 237ms/step - loss: 0.4098 - root_mean_squared_error: 0.4096 - val_loss: 0.4188 - val_root_mean_squared_error: 0.4179
# Epoch 46/50
# 187/187 [==============================] - 41s 222ms/step - loss: 0.4439 - root_mean_squared_error: 0.4446 - val_loss: 0.4392 - val_root_mean_squared_error: 0.4382
# Epoch 47/50
# 187/187 [==============================] - 40s 216ms/step - loss: 0.4396 - root_mean_squared_error: 0.4395 - val_loss: 0.4268 - val_root_mean_squared_error: 0.4259
# Epoch 48/50
# 187/187 [==============================] - 41s 219ms/step - loss: 0.4239 - root_mean_squared_error: 0.4247 - val_loss: 0.4328 - val_root_mean_squared_error: 0.4319
# Epoch 49/50
# 187/187 [==============================] - 47s 251ms/step - loss: 0.4265 - root_mean_squared_error: 0.4264 - val_loss: 0.4283 - val_root_mean_squared_error: 0.4273
# Epoch 50/50
# 187/187 [==============================] - 40s 212ms/step - loss: 0.4377 - root_mean_squared_error: 0.4375 - val_loss: 0.4304 - val_root_mean_squared_error: 0.4295

# %% [markdown]
# # Test Model

# %%
predictions = y_scaler.inverse_transform(model.predict_generator(x_test_scaled).reshape(-1,n_steps_out))
print(predictions.shape)

print(y_test.shape)
# Out:
# (863, 3)
# (863, 3)

# %%
predictions_train = y_scaler.inverse_transform(model.predict_generator(x_train_scaled).reshape(-1,n_steps_out))
print(predictions_train.shape)
print(y_train.shape)
# Out:
# (5979, 3)
# (5979, 3)

# %% [markdown]
# # Bentuk Prediksi ke Dataframe

# %%
real = y_test
real_train = y_train
predictions = pd.DataFrame(predictions)
predictions_for_train = pd.DataFrame(predictions_train)
real = pd.DataFrame(real)
real_train = pd.DataFrame(real_train)
print(predictions.shape)
print(real.shape)
print(predictions_for_train.shape)
print(real_train.shape)
# Out:
# (863, 3)
# (863, 3)
# (5979, 3)
# (5979, 3)

# %% [markdown]
# # Plot Model Test Dataset

# %%
real[0]
# Out:
# 0      0.137
# 1      0.143
# 2      0.136
# 3      0.219
# 4      0.119
#        ...
# 858    0.187
# 859    0.217
# 860    0.298
# 861    0.216
# 862    0.084
# Name: 0, Length: 863, dtype: float64

# %%
predictions[0]
# Out:
# 0      0.129568
# 1      0.132775
# 2      0.111714
# 3      0.217172
# 4      0.110526
#          ...
# 858    0.178317
# 859    0.195395
# 860    0.315305
# 861    0.167303
# 862    0.072882
# Name: 0, Length: 863, dtype: float32

# %%
real[1]
# Out:
# 0      0.136
# 1      0.150
# 2      0.151
# 3      0.226
# 4      0.111
#        ...
# 858    0.185
# 859    0.222
# 860    0.292
# 861    0.233
# 862    0.091
# Name: 1, Length: 863, dtype: float64

# %%
predictions[1]
# Out:
# 0      0.128595
# 1      0.134189
# 2      0.109616
# 3      0.217169
# 4      0.107474
#          ...
# 858    0.188071
# 859    0.198352
# 860    0.310061
# 861    0.167746
# 862    0.076961
# Name: 1, Length: 863, dtype: float32

# %%
real[2]
# Out:
# 0      0.135
# 1      0.154
# 2      0.162
# 3      0.223
# 4      0.106
#        ...
# 858    0.183
# 859    0.212
# 860    0.289
# 861    0.224
# 862    0.099
# Name: 2, Length: 863, dtype: float64

# %%
predictions[2]
# Out:
# 0      0.128117
# 1      0.136427
# 2      0.108919
# 3      0.219750
# 4      0.105917
#          ...
# 858    0.200937
# 859    0.204644
# 860    0.314692
# 861    0.168231
# 862    0.080856
# Name: 2, Length: 863, dtype: float32

# %%
df_final = []
df_final_train = []

for i in range(1, n_steps_out+1):
    df_final.append(pd.DataFrame())
    df_final_train.append(pd.DataFrame())

for i in range(0,n_steps_out):
    df_final[i]['Tinggi Muka Air Purwodadi'] = real[i]
    df_final[i]['Prediksi Tinggi Muka Air Purwodadi'] = predictions[i]
    df_final_train[i]['Tinggi Muka Air Purwodadi'] = real_train[i]
    df_final_train[i]['Prediksi Tinggi Muka Air Purwodadi'] = predictions_for_train[i]

    mpl.rcParams['figure.figsize'] = (30, 15)
    mpl.rcParams['axes.grid'] = False
    ax = df_final[i][['Tinggi Muka Air Purwodadi', 'Prediksi Tinggi Muka Air Purwodadi']].plot()
    ax.legend(["Actual", "Predicted"]) 
    ax.set_title(f"Prediksi Purwodadi T+{i+1}")

    plt.show()

# %% [markdown]
# # Plot Model Train Dataset

# %%
for i in range(0,n_steps_out):
    mpl.rcParams['figure.figsize'] = (40,20)
    mpl.rcParams['axes.grid'] = False
    ax = df_final_train[i][['Tinggi Muka Air Purwodadi', 'Prediksi Tinggi Muka Air Purwodadi']].plot()
    ax.legend(["Actual", "Predicted"]) 
    ax.set_title(f"Train Purwodadi T+{i+1}")

# %% [markdown]
# # Evaluation Score

# %%
rmse_scores = []
model_names = []
mse_scores = []
mape_scores = []
mae_scores = []

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_percentage_error

indicator = ['Tinggi Muka Air Purwodadi']

for j in range(0,n_steps_out): 
  for i in indicator:
    rmse_scores.append(mean_squared_error(df_final[j][f'{i}'],df_final[j][f'Prediksi {i}'], squared=False))
    mse_scores.append(mean_squared_error(df_final[j][f'{i}'],df_final[j][f'Prediksi {i}']))
    mae_scores.append(mean_absolute_error(df_final[j][f'{i}'], df_final[j][f'Prediksi {i}']))
    mape_scores.append(mean_absolute_percentage_error(df_final[j][f'{i}'], df_final[j][f'Prediksi {i}']))
    model_names.append(f"{i} T+{j+1}")

# %%
if all(len(arr) == len(model_names) for arr in [rmse_scores, mse_scores, mae_scores, mape_scores]):
    data = {'Fitur Yang Akan Diprediksi': model_names,
            'RMSE Score Prediction': rmse_scores,
            'MSE Score Prediction': mse_scores,
            'MAE Score Prediction': mae_scores,
            'MAPE Score Prediction': mape_scores}

    df_evaluation = pd.DataFrame(data)
    df_evaluation = df_evaluation.sort_values(by='RMSE Score Prediction', ascending=True)
    pd.set_option('display.float_format', '{:.2f}'.format)
    df_evaluation
else:
    print("Arrays have different lengths.")

# %%
df_evaluation
# Out:
#       Fitur Yang Akan Diprediksi  RMSE Score Prediction  MSE Score Prediction  \
# 0  Tinggi Muka Air Purwodadi T+1                   0.06                  0.00
# 2  Tinggi Muka Air Purwodadi T+3                   0.08                  0.01
# 1  Tinggi Muka Air Purwodadi T+2                   0.09                  0.01
#
#    MAE Score Prediction  MAPE Score Prediction
# 0                  0.02        129784292324.80
# 2                  0.03        144659965413.45
# 1                  0.03         31656278583.30

# %%
df_evaluation.to_excel('Purwodadi_TCN_Predict_T+3.xlsx')

# %% [markdown]
# # Perbandingan Selisih Dalam Angka

# %%
for i in range(0,n_steps_out):
    df_final[i] = df_final[i].round(2)
    df_final[i][f"Difference_Rerata Tinggi Muka Air T+{i+1} dan Prediksi Tinggi Muka Air T+{i+1}"] = abs(df_final[i]['Tinggi Muka Air Purwodadi'] - df_final[i]['Prediksi Tinggi Muka Air Purwodadi'])

# %%
df_final[0]
# Out:
#      Tinggi Muka Air Purwodadi  Prediksi Tinggi Muka Air Purwodadi  \
# 0                         0.14                                0.13
# 1                         0.14                                0.13
# 2                         0.14                                0.11
# 3                         0.22                                0.22
# 4                         0.12                                0.11
# ..                         ...                                 ...
# 858                       0.19                                0.18
# 859                       0.22                                0.20
# 860                       0.30                                0.32
# 861                       0.22                                0.17
# 862                       0.08                                0.07
#
#      Difference_Rerata Tinggi Muka Air T+1 dan Prediksi Tinggi Muka Air T+1
# 0                                                 0.01
# 1                                                 0.01
# 2                                                 0.03
# 3                                                 0.00
# 4                                                 0.01
# ..                                                 ...
# 858                                               0.01
# 859                                               0.02
# 860                                               0.02
# 861                                               0.05
# 862                                               0.01
#
# [863 rows x 3 columns]

# %% [markdown]
# # Save Model

# %%
model.save_weights('./checkpoints/my_checkpoint')

# %%
# !mkdir -p saved_model
model.save('saved_model/purwodadi_tcn')
model.save('purwodadi_tcn.h5')
# Out:
# INFO:tensorflow:Assets written to: saved_model/purwodadi_tcn/assets
# INFO:tensorflow:Assets written to: saved_model/purwodadi_tcn/assets

# %%
import pickle
with open('purwodadi_tcn_x_scaler.pkl', 'wb') as file:
    pickle.dump(x_scaler, file)
    
with open('purwodadi_tcn_y_scaler.pkl', 'wb') as file:
    pickle.dump(y_scaler, file)
