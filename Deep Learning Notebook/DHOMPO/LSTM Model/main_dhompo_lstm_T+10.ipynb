# %% [markdown]
# # Import Dependensi

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
from numpy import hstack
import tensorflow as tf
from numpy import array
from datetime import datetime, timedelta
import matplotlib as mpl
from tensorflow import keras
from keras import optimizers
from keras.models import Sequential
from keras.layers import LSTM, Dense, RepeatVector, TimeDistributed, Dropout, BatchNormalization, Activation
from sklearn.preprocessing import MinMaxScaler
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
# Out:
# Matplotlib created a temporary cache directory at /var/folders/86/7gxks06s07xch2nsjg8bfzhh0000gn/T/matplotlib-_om0cut6 because the default path (/Users/ingwerludwig/.matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %% [markdown]
# # Import Dataset

# %%
df = pd.read_excel('/Volumes/IngwerSSD/DATA/College/project-workspace/forecasting-dinas-sumber-daya air/Model Welang.xlsx','Data')
df.rename(columns={'Unnamed: 0': 'DateTime'}, inplace=True)
df['DateTime'] = pd.to_datetime(df['DateTime'])
df.sort_values(by='DateTime',ascending=True,inplace=True)
df
# Out:
#                 DateTime   RC   RL     LP     LD
# 0    2022-09-20 20:00:00  0.0  0.0  0.107  0.315
# 1    2022-09-20 21:00:00  0.0  0.0  0.108  0.307
# 2    2022-09-20 22:00:00  0.0  0.0  0.106  0.297
# 3    2022-09-20 23:00:00  0.0  0.0  0.108  0.293
# 4    2022-09-21 00:00:00  0.0  0.0  0.111  0.292
# ...                  ...  ...  ...    ...    ...
# 8611 2023-09-15 08:00:00  0.0  0.0  0.070  0.213
# 8612 2023-09-15 09:00:00  0.0  0.0  0.080  0.228
# 8613 2023-09-15 10:00:00  0.0  0.0  0.089  0.237
# 8614 2023-09-15 11:00:00  0.0  0.0  0.096  0.245
# 8615 2023-09-15 12:00:00  0.0  0.0  0.099  0.251
#
# [8616 rows x 5 columns]

# %% [markdown]
# # Isi Data yang tidak Sekuensial 1 Jam dengan Data Sebelumnya

# %%
check_df = df['DateTime']
check_df = pd.DataFrame(check_df)

check_df['TimeDifference'] = check_df['DateTime'].diff()
expected_interval = pd.to_timedelta('1 hour')
check_df['not_sequential'] = check_df['TimeDifference'] != expected_interval

check_df.at[0, 'not_sequential'] = False
filtered_df = check_df[check_df['not_sequential']]
filtered_df
# Out:
#                 DateTime  TimeDifference  not_sequential
# 14   2022-09-21 11:00:00 0 days 02:00:00            True
# 15   2022-09-21 13:00:00 0 days 02:00:00            True
# 17   2022-09-21 16:00:00 0 days 02:00:00            True
# 65   2022-09-23 17:00:00 0 days 02:00:00            True
# 1386 2022-11-17 21:00:00 0 days 04:00:00            True
# 2158 2022-12-20 04:00:00 0 days 04:00:00            True
# 4254 2023-03-17 13:00:00 0 days 02:00:00            True
# 4303 2023-03-19 17:00:00 0 days 04:00:00            True
# 4397 2023-03-23 17:00:00 0 days 03:00:00            True
# 4465 2023-03-26 14:00:00 0 days 02:00:00            True

# %%
start_date = df['DateTime'].min()
end_date = df['DateTime'].max()
date_range = pd.date_range(start=start_date, end=end_date, freq='1H')
sequence_df = pd.DataFrame({'DateTime': date_range})

df = pd.merge_asof(sequence_df, df, on='DateTime', direction='backward')

# Forward-fill missing values in the 'Akumulasi Curah Hujan Cendono' column
df['RC'].fillna(method='ffill', inplace=True)
df['RC'] = df['RC'].round(3).astype(float)

df['RL'].fillna(method='ffill', inplace=True)
df['RL'] = df['RL'].round(3).astype(float)

df['LP'].fillna(method='ffill', inplace=True)
df['LP'] = df['LP'].round(3).astype(float)

df['LD'].fillna(method='ffill', inplace=True)
df['LD'] = df['LD'].round(3).astype(float)
df
# Out:
#                 DateTime   RC   RL     LP     LD
# 0    2022-09-20 20:00:00  0.0  0.0  0.107  0.315
# 1    2022-09-20 21:00:00  0.0  0.0  0.108  0.307
# 2    2022-09-20 22:00:00  0.0  0.0  0.106  0.297
# 3    2022-09-20 23:00:00  0.0  0.0  0.108  0.293
# 4    2022-09-21 00:00:00  0.0  0.0  0.111  0.292
# ...                  ...  ...  ...    ...    ...
# 8628 2023-09-15 08:00:00  0.0  0.0  0.070  0.213
# 8629 2023-09-15 09:00:00  0.0  0.0  0.080  0.228
# 8630 2023-09-15 10:00:00  0.0  0.0  0.089  0.237
# 8631 2023-09-15 11:00:00  0.0  0.0  0.096  0.245
# 8632 2023-09-15 12:00:00  0.0  0.0  0.099  0.251
#
# [8633 rows x 5 columns]

# %%
check_df = df['DateTime']
check_df = pd.DataFrame(check_df)

check_df['TimeDifference'] = check_df['DateTime'].diff()
expected_interval = pd.to_timedelta('1 hour')
check_df['not_sequential'] = check_df['TimeDifference'] != expected_interval

# Fill the first row with False since it doesn't have a previous row for comparison
check_df.at[0, 'not_sequential'] = False
filtered_df = check_df[check_df['not_sequential']]
filtered_df
# Out:
# Empty DataFrame
# Columns: [DateTime, TimeDifference, not_sequential]
# Index: []

# %%
df.to_excel('Fix Data_Model Welang.xlsx')

# %% [markdown]
# # Load Dataset Baru

# %%
merge_df = pd.read_excel('Fix Data_Model Welang.xlsx')
merge_df.drop('Unnamed: 0',axis=1,inplace=True)
merge_df['DateTime'] = pd.to_datetime(merge_df['DateTime'])
merge_df.sort_values(by='DateTime',ascending=True,inplace=True)
merge_df
# Out:
#                 DateTime   RC   RL     LP     LD
# 0    2022-09-20 20:00:00  0.0  0.0  0.107  0.315
# 1    2022-09-20 21:00:00  0.0  0.0  0.108  0.307
# 2    2022-09-20 22:00:00  0.0  0.0  0.106  0.297
# 3    2022-09-20 23:00:00  0.0  0.0  0.108  0.293
# 4    2022-09-21 00:00:00  0.0  0.0  0.111  0.292
# ...                  ...  ...  ...    ...    ...
# 8628 2023-09-15 08:00:00  0.0  0.0  0.070  0.213
# 8629 2023-09-15 09:00:00  0.0  0.0  0.080  0.228
# 8630 2023-09-15 10:00:00  0.0  0.0  0.089  0.237
# 8631 2023-09-15 11:00:00  0.0  0.0  0.096  0.245
# 8632 2023-09-15 12:00:00  0.0  0.0  0.099  0.251
#
# [8633 rows x 5 columns]

# %%
plt.plot(merge_df['LD'])

# %% [markdown]
# # Cek data dengan nilai 0 selain di Curah Hujan

# %%
columns_to_replace = [
    'LP',
    'LD'
]

mask = (merge_df[columns_to_replace] == 0).any(axis=1)
filtered_rows = merge_df[mask]
filtered_rows.sort_values(by='DateTime')
# Out:
#                 DateTime   RC   RL   LP     LD
# 7866 2023-08-14 14:00:00  0.0  0.0  0.0  0.179
# 7884 2023-08-15 08:00:00  0.0  0.0  0.0  0.196
# 7885 2023-08-15 09:00:00  0.0  0.0  0.0  0.201
# 7886 2023-08-15 10:00:00  0.0  0.0  0.0  0.202
# 7887 2023-08-15 11:00:00  0.0  0.0  0.0  0.199
# 7888 2023-08-15 12:00:00  0.0  0.0  0.0  0.197
# 7889 2023-08-15 13:00:00  0.0  0.0  0.0  0.193
# 7890 2023-08-15 14:00:00  0.0  0.0  0.0  0.189
# 7907 2023-08-16 07:00:00  0.0  0.0  0.0  0.180
# 7908 2023-08-16 08:00:00  0.0  0.0  0.0  0.177
# 7909 2023-08-16 09:00:00  0.0  0.0  0.0  0.171
# 7910 2023-08-16 10:00:00  0.0  0.0  0.0  0.167
# 7911 2023-08-16 11:00:00  0.0  0.0  0.0  0.174
# 7912 2023-08-16 12:00:00  0.0  0.0  0.0  0.193
# 7913 2023-08-16 13:00:00  0.0  0.0  0.0  0.220
# 7914 2023-08-16 14:00:00  0.0  0.0  0.0  0.237
# 7915 2023-08-16 15:00:00  0.0  0.0  0.0  0.251
# 7931 2023-08-17 07:00:00  0.0  0.0  0.0  0.171
# 7932 2023-08-17 08:00:00  0.0  0.0  0.0  0.167
# 7933 2023-08-17 09:00:00  0.0  0.0  0.0  0.166
# 7934 2023-08-17 10:00:00  0.0  0.0  0.0  0.160
# 7935 2023-08-17 11:00:00  0.0  0.0  0.0  0.172
# 7936 2023-08-17 12:00:00  0.0  0.0  0.0  0.193
# 7937 2023-08-17 13:00:00  0.0  0.0  0.0  0.239
# 7938 2023-08-17 14:00:00  0.0  0.0  0.0  0.239
# 7939 2023-08-17 15:00:00  0.0  0.0  0.0  0.235
# 7980 2023-08-19 08:00:00  0.0  0.0  0.0  0.266
# 7981 2023-08-19 09:00:00  0.0  0.0  0.0  0.293
# 7982 2023-08-19 10:00:00  0.0  0.0  0.0  0.299
# 7983 2023-08-19 11:00:00  0.0  0.0  0.0  0.287
# 7984 2023-08-19 12:00:00  0.0  0.0  0.0  0.326
# 7985 2023-08-19 13:00:00  0.0  0.0  0.0  0.313
# 7986 2023-08-19 14:00:00  0.0  0.0  0.0  0.304
# 7987 2023-08-19 15:00:00  0.0  0.0  0.0  0.297
# 8481 2023-09-09 05:00:00  0.0  0.0  0.0  0.181

# %% [markdown]
# # Visualisasi Tren

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
copy_df_2 = merge_df.iloc[48:144,:]
copy_df_2 = copy_df_2.set_index('DateTime')
copy_df_2.index.freq = 'H'

# %%
results = seasonal_decompose(copy_df_2['LD'])
plt.figure(figsize=(42, 24))
results.plot()
plt.show()

# %% [markdown]
# # Ekstrak Fitur Datetime untuk digunakan dalam TimeSeries Forecasting

# %%
test = merge_df.iloc[0:1,0]
test
# Out:
# 0   2022-09-20 20:00:00
# Name: DateTime, dtype: datetime64[ns]

# %%
print(test.dt.hour)
# Out:
# 0    20
# Name: DateTime, dtype: int64

# %%
merge_df['hour_at'] = merge_df['DateTime'].dt.hour
merge_df
# Out:
#                 DateTime   RC   RL     LP     LD  hour_at
# 0    2022-09-20 20:00:00  0.0  0.0  0.107  0.315       20
# 1    2022-09-20 21:00:00  0.0  0.0  0.108  0.307       21
# 2    2022-09-20 22:00:00  0.0  0.0  0.106  0.297       22
# 3    2022-09-20 23:00:00  0.0  0.0  0.108  0.293       23
# 4    2022-09-21 00:00:00  0.0  0.0  0.111  0.292        0
# ...                  ...  ...  ...    ...    ...      ...
# 8628 2023-09-15 08:00:00  0.0  0.0  0.070  0.213        8
# 8629 2023-09-15 09:00:00  0.0  0.0  0.080  0.228        9
# 8630 2023-09-15 10:00:00  0.0  0.0  0.089  0.237       10
# 8631 2023-09-15 11:00:00  0.0  0.0  0.096  0.245       11
# 8632 2023-09-15 12:00:00  0.0  0.0  0.099  0.251       12
#
# [8633 rows x 6 columns]

# %% [markdown]
# # Visualisasi Jam Terhadap Rerata Muka Air Dhompo

# %%
plt.figure(figsize=(10,10))
plt.scatter(x='hour_at',y='LD',data=merge_df)
plt.xlabel('hour_at')
plt.ylabel('Rerata Tinggi Muka Air Dhompo')
# Out:
# Text(0, 0.5, 'Rerata Tinggi Muka Air Dhompo')

# %% [markdown]
# # Mutivariat Sekuens untuk Input dan Output LSTM

# %%
def split_sequences_sliding(sequences, n_steps_in, n_steps_out, step=1):
    X, y = list(), list()
    for i in range(0, len(sequences) - n_steps_in - n_steps_out + 1, step):
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out
        seq_x, seq_y = sequences[i:end_ix, :], sequences[end_ix:out_end_ix, :]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %% [markdown]
# # Train Test Split

# %%
merge_df.drop(['DateTime','hour_at'],axis=1,inplace=True)
merge_df
# Out:
#        RC   RL     LP     LD
# 0     0.0  0.0  0.107  0.315
# 1     0.0  0.0  0.108  0.307
# 2     0.0  0.0  0.106  0.297
# 3     0.0  0.0  0.108  0.293
# 4     0.0  0.0  0.111  0.292
# ...   ...  ...    ...    ...
# 8628  0.0  0.0  0.070  0.213
# 8629  0.0  0.0  0.080  0.228
# 8630  0.0  0.0  0.089  0.237
# 8631  0.0  0.0  0.096  0.245
# 8632  0.0  0.0  0.099  0.251
#
# [8633 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
train_percent = 0.7
validation_percent = 0.2

new_merge_df = merge_df
train_size = int(len(new_merge_df) * train_percent)
validation_size = int(len(new_merge_df) * validation_percent)

df_train = new_merge_df[:train_size]
df_validation = new_merge_df[train_size:(train_size + validation_size)]
df_test = new_merge_df[train_size + validation_size:]

print('Data for train:', df_train.shape)
print('Total day for train:', df_train.shape[0]/24)
print('\nData for validation:', df_validation.shape)
print('Total day for validation:', df_validation.shape[0]/24)
print('\nData for test:', df_test.shape)
print('Total day for test:', df_test.shape[0]/24)
# Out:
# Data for train: (6043, 4)
# Total day for train: 251.79166666666666
#
# Data for validation: (1726, 4)
# Total day for validation: 71.91666666666667
#
# Data for test: (864, 4)
# Total day for test: 36.0

# %%
plt.plot(df_train['LD'])

# %% [markdown]
# # Konfigurasi Multivariat Sekuens Input / Output

# %% [markdown]
# Menggunakan 6 jam sebelumnya untuk memprediksi 4 jam kedepan </br>
# Contoh sekarang jam 07.00, data 01.00 - 06.00 akan digunakan untuk memprediksi data 08.00, 09.00, 10.00

# %%
from sklearn.preprocessing import MinMaxScaler

# Define the sliding window size
n_steps_in, n_steps_out = 10, 5

# Create x and y sequences for training data
x_train, y_train = split_sequences_sliding(df_train.to_numpy(), n_steps_in, n_steps_out)
x_train = x_train.reshape(-1, 4)
y_train = y_train[:, :, -1].reshape(-1, 5)  # Adjust the shape for the output

# Create x and y sequences for validation data
x_val, y_val = split_sequences_sliding(df_validation.to_numpy(), n_steps_in, n_steps_out)
x_val = x_val.reshape(-1, 4)
y_val = y_val[:, :, -1].reshape(-1, 5)  # Adjust the shape for the output

# Create x and y sequences for test data
x_test, y_test = split_sequences_sliding(df_test.to_numpy(), n_steps_in, n_steps_out)
x_test = x_test.reshape(-1, 4)
y_test = y_test[:, :, -1].reshape(-1, 5)  # Adjust the shape for the output

# Initialize MinMaxScaler for x and y
x_scaler = MinMaxScaler()
y_scaler = MinMaxScaler()

# Fit and transform x data
x_train_scaled = x_scaler.fit_transform(x_train)
x_val_scaled = x_scaler.transform(x_val)
x_test_scaled = x_scaler.transform(x_test)

# Fit and transform y data
y_train_scaled = y_scaler.fit_transform(y_train)
y_val_scaled = y_scaler.transform(y_val)
y_test_scaled = y_scaler.transform(y_test)

# Reshape x_train_scaled, x_val_scaled, and x_test_scaled back to 3D
x_train_scaled = x_train_scaled.reshape(-1, n_steps_in, 4)
x_val_scaled = x_val_scaled.reshape(-1, n_steps_in, 4)
x_test_scaled = x_test_scaled.reshape(-1, n_steps_in, 4)

# Define the number of features
n_features = x_train.shape[1]

# %%
df_test
# Out:
#        RC   RL     LP     LD
# 7769  0.0  0.0  0.071  0.196
# 7770  0.0  0.0  0.071  0.183
# 7771  0.0  0.0  0.068  0.164
# 7772  0.0  0.0  0.061  0.138
# 7773  0.0  0.0  0.049  0.131
# ...   ...  ...    ...    ...
# 8628  0.0  0.0  0.070  0.213
# 8629  0.0  0.0  0.080  0.228
# 8630  0.0  0.0  0.089  0.237
# 8631  0.0  0.0  0.096  0.245
# 8632  0.0  0.0  0.099  0.251
#
# [864 rows x 4 columns]

# %%
x_test
# Out:
# array([[0.   , 0.   , 0.071, 0.196],
#        [0.   , 0.   , 0.071, 0.183],
#        [0.   , 0.   , 0.068, 0.164],
#        ...,
#        [0.   , 0.   , 0.036, 0.145],
#        [0.   , 0.   , 0.044, 0.161],
#        [0.   , 0.   , 0.057, 0.194]])

# %%
x_test_scaled
# Out:
# array([[[ 0.        ,  0.        ,  0.03103983,  0.00786434],
#         [ 0.        ,  0.        ,  0.03103983,  0.00466945],
#         [ 0.        ,  0.        ,  0.02948784,  0.        ],
#         ...,
#         [ 0.        ,  0.        ,  0.00620797,  0.00098304],
#         [ 0.        ,  0.        ,  0.00931195,  0.0068813 ],
#         [ 0.        ,  0.        ,  0.00931195,  0.01179651]],
#
#        [[ 0.        ,  0.        ,  0.03103983,  0.00466945],
#         [ 0.        ,  0.        ,  0.02948784,  0.        ],
#         [ 0.        ,  0.        ,  0.02586653, -0.00638978],
#         ...,
#         [ 0.        ,  0.        ,  0.00931195,  0.0068813 ],
#         [ 0.        ,  0.        ,  0.00931195,  0.01179651],
#         [ 0.        ,  0.        ,  0.00982928,  0.01597444]],
#
#        [[ 0.        ,  0.        ,  0.02948784,  0.        ],
#         [ 0.        ,  0.        ,  0.02586653, -0.00638978],
#         [ 0.        ,  0.        ,  0.01965856, -0.0081101 ],
#         ...,
#         [ 0.        ,  0.        ,  0.00931195,  0.01179651],
#         [ 0.        ,  0.        ,  0.00982928,  0.01597444],
#         [ 0.        ,  0.        ,  0.00931195,  0.01572868]],
#
#        ...,
#
#        [[ 0.        ,  0.        ,  0.01396793,  0.00860162],
#         [ 0.        ,  0.        ,  0.01345059,  0.00442369],
#         [ 0.        ,  0.        ,  0.01241593,  0.00221185],
#         ...,
#         [ 0.        ,  0.        ,  0.0118986 , -0.00270337],
#         [ 0.        ,  0.        ,  0.01293326, -0.00368641],
#         [ 0.        ,  0.        ,  0.01293326, -0.00466945]],
#
#        [[ 0.        ,  0.        ,  0.01345059,  0.00442369],
#         [ 0.        ,  0.        ,  0.01241593,  0.00221185],
#         [ 0.        ,  0.        ,  0.01034661, -0.00368641],
#         ...,
#         [ 0.        ,  0.        ,  0.01293326, -0.00368641],
#         [ 0.        ,  0.        ,  0.01293326, -0.00466945],
#         [ 0.        ,  0.        ,  0.01707191, -0.00073728]],
#
#        [[ 0.        ,  0.        ,  0.01241593,  0.00221185],
#         [ 0.        ,  0.        ,  0.01034661, -0.00368641],
#         [ 0.        ,  0.        ,  0.00879462, -0.00491521],
#         ...,
#         [ 0.        ,  0.        ,  0.01293326, -0.00466945],
#         [ 0.        ,  0.        ,  0.01707191, -0.00073728],
#         [ 0.        ,  0.        ,  0.02379721,  0.00737282]]])

# %%
print('Total features:', n_features)
print('Total train data:', x_train_scaled.shape)
print('Total validation data:', x_val_scaled.shape)
print('Total test data:', x_test_scaled.shape)
# Out:
# Total features: 4
# Total train data: (6029, 10, 4)
# Total validation data: (1712, 10, 4)
# Total test data: (850, 10, 4)

# %%
print('x_train_scaled shape:', x_train_scaled.shape)
print('y_train_scaled shape:', y_train_scaled.shape)
print('x_val_scaled shape:', x_val_scaled.shape)
print('y_val_scaled shape:', y_val_scaled.shape)
# Out:
# x_train_scaled shape: (6029, 10, 4)
# y_train_scaled shape: (6029, 5)
# x_val_scaled shape: (1712, 10, 4)
# y_val_scaled shape: (1712, 5)

# %% [markdown]
# # Training Model

# %%
model = Sequential()

model.add(LSTM(300, input_shape=(n_steps_in, n_features)))
model.add(RepeatVector(n_steps_out))
model.add(LSTM(300, return_sequences=True))
model.add(Activation('relu'))
model.add(TimeDistributed(Dense(1)))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 300)               366000
#
#  repeat_vector (RepeatVecto  (None, 5, 300)            0
#  r)
#
#  lstm_1 (LSTM)               (None, 5, 300)            721200
#
#  activation (Activation)     (None, 5, 300)            0
#
#  time_distributed (TimeDist  (None, 5, 1)              301
#  ributed)
#
# =================================================================
# Total params: 1087501 (4.15 MB)
# Trainable params: 1087501 (4.15 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Model Tuning

# %%
from keras import backend as K

def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %% [markdown]
# # Fit Model

# %%
epoch = 50
model.compile(optimizer='adam', loss='mae', metrics=['mae'])
model.fit(x_train_scaled, y_train_scaled, batch_size=1,epochs=epoch, validation_data=(x_val_scaled, y_val_scaled))
# Out:
# Epoch 1/50
# 6029/6029 [==============================] - 97s 15ms/step - loss: 0.0291 - mae: 0.0291 - val_loss: 0.0084 - val_mae: 0.0084
# Epoch 2/50
# 6029/6029 [==============================] - 92s 15ms/step - loss: 0.0257 - mae: 0.0257 - val_loss: 0.0076 - val_mae: 0.0076
# Epoch 3/50
# 6029/6029 [==============================] - 91s 15ms/step - loss: 0.0251 - mae: 0.0251 - val_loss: 0.0090 - val_mae: 0.0090
# Epoch 4/50
# 6029/6029 [==============================] - 91s 15ms/step - loss: 0.0246 - mae: 0.0246 - val_loss: 0.0074 - val_mae: 0.0074
# Epoch 5/50
# 6029/6029 [==============================] - 96s 16ms/step - loss: 0.0242 - mae: 0.0242 - val_loss: 0.0068 - val_mae: 0.0068
# Epoch 6/50
# 6029/6029 [==============================] - 94s 16ms/step - loss: 0.0240 - mae: 0.0240 - val_loss: 0.0068 - val_mae: 0.0068
# Epoch 7/50
# 6029/6029 [==============================] - 94s 16ms/step - loss: 0.0237 - mae: 0.0237 - val_loss: 0.0126 - val_mae: 0.0126
# Epoch 8/50
# 6029/6029 [==============================] - 91s 15ms/step - loss: 0.0235 - mae: 0.0235 - val_loss: 0.0073 - val_mae: 0.0073
# Epoch 9/50
# 6029/6029 [==============================] - 91s 15ms/step - loss: 0.0236 - mae: 0.0236 - val_loss: 0.0074 - val_mae: 0.0074
# Epoch 10/50
# 6029/6029 [==============================] - 92s 15ms/step - loss: 0.0233 - mae: 0.0233 - val_loss: 0.0082 - val_mae: 0.0082
# Epoch 11/50
# 6029/6029 [==============================] - 92s 15ms/step - loss: 0.0231 - mae: 0.0231 - val_loss: 0.0109 - val_mae: 0.0109
# Epoch 12/50
# 6029/6029 [==============================] - 92s 15ms/step - loss: 0.0230 - mae: 0.0230 - val_loss: 0.0073 - val_mae: 0.0073
# Epoch 13/50
# 6029/6029 [==============================] - 92s 15ms/step - loss: 0.0231 - mae: 0.0231 - val_loss: 0.0069 - val_mae: 0.0069
# Epoch 14/50
# 6029/6029 [==============================] - 97s 16ms/step - loss: 0.0229 - mae: 0.0229 - val_loss: 0.0062 - val_mae: 0.0062
# Epoch 15/50
# 6029/6029 [==============================] - 98s 16ms/step - loss: 0.0228 - mae: 0.0228 - val_loss: 0.0069 - val_mae: 0.0069
# Epoch 16/50
# 6029/6029 [==============================] - 99s 16ms/step - loss: 0.0228 - mae: 0.0228 - val_loss: 0.0064 - val_mae: 0.0064
# Epoch 17/50
# 6029/6029 [==============================] - 100s 17ms/step - loss: 0.0225 - mae: 0.0225 - val_loss: 0.0086 - val_mae: 0.0086
# Epoch 18/50
# 6029/6029 [==============================] - 102s 17ms/step - loss: 0.0228 - mae: 0.0228 - val_loss: 0.0089 - val_mae: 0.0089
# Epoch 19/50
# 6029/6029 [==============================] - 101s 17ms/step - loss: 0.0225 - mae: 0.0225 - val_loss: 0.0058 - val_mae: 0.0058
# Epoch 20/50
# 6029/6029 [==============================] - 99s 16ms/step - loss: 0.0225 - mae: 0.0225 - val_loss: 0.0061 - val_mae: 0.0061
# Epoch 21/50
# 6029/6029 [==============================] - 100s 17ms/step - loss: 0.0224 - mae: 0.0224 - val_loss: 0.0076 - val_mae: 0.0076
# Epoch 22/50
# 6029/6029 [==============================] - 100s 17ms/step - loss: 0.0224 - mae: 0.0224 - val_loss: 0.0071 - val_mae: 0.0071
# Epoch 23/50
# 6029/6029 [==============================] - 102s 17ms/step - loss: 0.0223 - mae: 0.0223 - val_loss: 0.0069 - val_mae: 0.0069
# Epoch 24/50
# 6029/6029 [==============================] - 107s 18ms/step - loss: 0.0222 - mae: 0.0222 - val_loss: 0.0074 - val_mae: 0.0074
# Epoch 25/50
# 6029/6029 [==============================] - 107s 18ms/step - loss: 0.0222 - mae: 0.0222 - val_loss: 0.0064 - val_mae: 0.0064
# Epoch 26/50
# 6029/6029 [==============================] - 140s 23ms/step - loss: 0.0221 - mae: 0.0221 - val_loss: 0.0079 - val_mae: 0.0079
# Epoch 27/50
# 6029/6029 [==============================] - 138s 23ms/step - loss: 0.0220 - mae: 0.0220 - val_loss: 0.0073 - val_mae: 0.0073
# Epoch 28/50
# 6029/6029 [==============================] - 124s 21ms/step - loss: 0.0219 - mae: 0.0219 - val_loss: 0.0054 - val_mae: 0.0054
# Epoch 29/50
# 6029/6029 [==============================] - 122s 20ms/step - loss: 0.0220 - mae: 0.0220 - val_loss: 0.0073 - val_mae: 0.0073
# Epoch 30/50
# 6029/6029 [==============================] - 124s 20ms/step - loss: 0.0218 - mae: 0.0218 - val_loss: 0.0064 - val_mae: 0.0064
# Epoch 31/50
# 6029/6029 [==============================] - 126s 21ms/step - loss: 0.0218 - mae: 0.0218 - val_loss: 0.0059 - val_mae: 0.0059
# Epoch 32/50
# 6029/6029 [==============================] - 142s 23ms/step - loss: 0.0217 - mae: 0.0217 - val_loss: 0.0063 - val_mae: 0.0063
# Epoch 33/50
# 6029/6029 [==============================] - 139s 23ms/step - loss: 0.0217 - mae: 0.0217 - val_loss: 0.0071 - val_mae: 0.0071
# Epoch 34/50
# 6029/6029 [==============================] - 154s 25ms/step - loss: 0.0217 - mae: 0.0217 - val_loss: 0.0069 - val_mae: 0.0069
# Epoch 35/50
# 6029/6029 [==============================] - 153s 25ms/step - loss: 0.0215 - mae: 0.0215 - val_loss: 0.0104 - val_mae: 0.0104
# Epoch 36/50
# 6029/6029 [==============================] - 148s 25ms/step - loss: 0.0215 - mae: 0.0215 - val_loss: 0.0056 - val_mae: 0.0056
# Epoch 37/50
# 6029/6029 [==============================] - 155s 26ms/step - loss: 0.0214 - mae: 0.0214 - val_loss: 0.0058 - val_mae: 0.0058
# Epoch 38/50
# 6029/6029 [==============================] - 163s 27ms/step - loss: 0.0214 - mae: 0.0214 - val_loss: 0.0062 - val_mae: 0.0062
# Epoch 39/50
# 6029/6029 [==============================] - 162s 27ms/step - loss: 0.0214 - mae: 0.0214 - val_loss: 0.0070 - val_mae: 0.0070
# Epoch 40/50
# 6029/6029 [==============================] - 168s 28ms/step - loss: 0.0215 - mae: 0.0215 - val_loss: 0.0067 - val_mae: 0.0067
# Epoch 41/50
# 6029/6029 [==============================] - 169s 28ms/step - loss: 0.0212 - mae: 0.0212 - val_loss: 0.0059 - val_mae: 0.0059
# Epoch 42/50
# 6029/6029 [==============================] - 152s 25ms/step - loss: 0.0213 - mae: 0.0213 - val_loss: 0.0080 - val_mae: 0.0080
# Epoch 43/50
# 6029/6029 [==============================] - 151s 25ms/step - loss: 0.0212 - mae: 0.0212 - val_loss: 0.0067 - val_mae: 0.0067
# Epoch 44/50
# 6029/6029 [==============================] - 156s 26ms/step - loss: 0.0212 - mae: 0.0212 - val_loss: 0.0072 - val_mae: 0.0072
# Epoch 45/50
# 6029/6029 [==============================] - 165s 27ms/step - loss: 0.0211 - mae: 0.0211 - val_loss: 0.0088 - val_mae: 0.0088
# Epoch 46/50
# 6029/6029 [==============================] - 160s 26ms/step - loss: 0.0211 - mae: 0.0211 - val_loss: 0.0062 - val_mae: 0.0062
# Epoch 47/50
# 6029/6029 [==============================] - 157s 26ms/step - loss: 0.0209 - mae: 0.0209 - val_loss: 0.0053 - val_mae: 0.0053
# Epoch 48/50
# 6029/6029 [==============================] - 149s 25ms/step - loss: 0.0209 - mae: 0.0209 - val_loss: 0.0072 - val_mae: 0.0072
# Epoch 49/50
# 6029/6029 [==============================] - 122s 20ms/step - loss: 0.0210 - mae: 0.0210 - val_loss: 0.0064 - val_mae: 0.0064
# Epoch 50/50
# 6029/6029 [==============================] - 144s 24ms/step - loss: 0.0209 - mae: 0.0209 - val_loss: 0.0051 - val_mae: 0.0051

# %% [markdown]
# # Test Model

# %%
predictions = y_scaler.inverse_transform(model.predict_generator(x_test_scaled).reshape(-1,n_steps_out))
print(predictions.shape)
print(y_test.shape)
# Out:
# (850, 5)
# (850, 5)

# %%
predictions_train = y_scaler.inverse_transform(model.predict_generator(x_train_scaled).reshape(-1,n_steps_out))
print(predictions_train.shape)
print(y_train.shape)
# Out:
# (6029, 5)
# (6029, 5)

# %% [markdown]
# # Bentuk Prediksi ke Dataframe

# %%
real = y_test
real_train = y_train

# rescale predictions
predictions = pd.DataFrame(predictions)
predictions = predictions
predictions = pd.DataFrame(predictions)

predictions_for_train = pd.DataFrame(predictions_train)
predictions_for_train = predictions_train
predictions_for_train = pd.DataFrame(predictions_train)

real = pd.DataFrame(real)
real = real
real = pd.DataFrame(real)

real_train = pd.DataFrame(real_train)
real_train =real_train
real_train = pd.DataFrame(real_train)

print(predictions.shape)
print(real.shape)

print(predictions_for_train.shape)
print(real_train.shape)
# Out:
# (850, 5)
# (850, 5)
# (6029, 5)
# (6029, 5)

# %%
df_final = pd.DataFrame()
df_final_train = pd.DataFrame()

# %%
df_final['Tinggi Muka Air Dhompo'] = real[4]
df_final['Prediksi Tinggi Muka Air Dhompo'] = predictions[4]

# %%
df_final_train['Tinggi Muka Air Dhompo'] = real_train[4]
df_final_train['Prediksi Tinggi Muka Air Dhompo'] = predictions_for_train[4]

# %% [markdown]
# # Plot Model Test Dataset

# %%
mpl.rcParams['figure.figsize'] = (20,10)
mpl.rcParams['axes.grid'] = False
df_final[['Tinggi Muka Air Dhompo', 'Prediksi Tinggi Muka Air Dhompo']].plot()
# Out:
# <Axes: >

# %% [markdown]
# # Plot Model Train Dataset

# %%
mpl.rcParams['figure.figsize'] = (20,10)
mpl.rcParams['axes.grid'] = False
df_final_train[['Tinggi Muka Air Dhompo', 'Prediksi Tinggi Muka Air Dhompo']].plot()
# Out:
# <Axes: >

# %% [markdown]
# # Evaluation Score

# %%
rmse_scores = []
model_names = []
mse_scores = []
mape_scores = []
mae_scores = []

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_percentage_error

indicator = [ 'Tinggi Muka Air Dhompo']

for i in indicator:
  rmse_scores.append(mean_squared_error(df_final[f'{i}'],df_final[f'Prediksi {i}'], squared=False))
  mse_scores.append(mean_squared_error(df_final[f'{i}'],df_final[f'Prediksi {i}']))
  mae_scores.append(mean_absolute_error(df_final[f'{i}'], df_final[f'Prediksi {i}']))
  mape_scores.append(mean_absolute_percentage_error(df_final[f'{i}'], df_final[f'Prediksi {i}']))
  model_names.append(i)

# %%
data = {'Fitur Yang Akan Diprediksi': model_names, 'RMSE Score Prediction': rmse_scores, 'MSE Score Prediction': mse_scores,'MAE Score Prediction': mae_scores, 'MAPE Score Prediction' : mape_scores}
df_evaluation = pd.DataFrame(data)
df_evaluation = df_evaluation.sort_values(by='RMSE Score Prediction', ascending=True)
pd.set_option('display.float_format', '{:.2f}'.format)
df_evaluation
# Out:
#   Fitur Yang Akan Diprediksi  RMSE Score Prediction  MSE Score Prediction  \
# 0     Tinggi Muka Air Dhompo                   0.01                  0.00
#
#    MAE Score Prediction  MAPE Score Prediction
# 0                  0.01                   0.05

# %%
df_evaluation.to_excel('LSTM_RNN_result.xlsx')

# %% [markdown]
# # Perbandingan Selisih Dalam Angka

# %%
df_final = df_final.round(2)

df_final['Difference_Rerata'] = abs(df_final['Tinggi Muka Air Dhompo'] - df_final['Prediksi Tinggi Muka Air Dhompo'])
df_final
# Out:
#      Tinggi Muka Air Dhompo  Prediksi Tinggi Muka Air Dhompo  \
# 0                      0.12                             0.13
# 1                      0.13                             0.12
# 2                      0.17                             0.14
# 3                      0.19                             0.20
# 4                      0.21                             0.21
# ..                      ...                              ...
# 854                    0.21                             0.23
# 855                    0.23                             0.23
# 856                    0.24                             0.24
# 857                    0.24                             0.25
# 858                    0.25                             0.26
#
#      Difference_Rerata
# 0                 0.01
# 1                 0.01
# 2                 0.03
# 3                 0.01
# 4                 0.00
# ..                 ...
# 854               0.02
# 855               0.00
# 856               0.00
# 857               0.01
# 858               0.01
#
# [859 rows x 3 columns]

# %%
test = df_final.sort_values(by='Difference_Rerata', ascending=False)
test[test['Difference_Rerata']>0.10].head(20)
# Out:
#      Tinggi Muka Air Dhompo  Prediksi Tinggi Muka Air Dhompo  \
# 294                    0.31                             0.18
# 295                    0.34                             0.46
#
#      Difference_Rerata
# 294               0.13
# 295               0.12

# %% [markdown]
# # Save Model

# %%
model.save_weights('./checkpoints/my_checkpoint')

# %%
# !mkdir -p saved_model
model.save('saved_model/muka_air_dhompo/ffws-model-batch-1-300-5-hari')
model.save('muka_air_dhompo_ffws-model-batch-1-300-neuron-5-hari.h5')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_44_layer_call_fn, lstm_cell_44_layer_call_and_return_conditional_losses, lstm_cell_45_layer_call_fn, lstm_cell_45_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: saved_model/muka_air_dhompo/ffws-model-batch-1-300-5-hari/assets
# INFO:tensorflow:Assets written to: saved_model/muka_air_dhompo/ffws-model-batch-1-300-5-hari/assets

# %%
import pickle
with open('dhompo_lstm_x_scaler.pkl', 'wb') as file:
    pickle.dump(x_scaler, file)
    
with open('dhompo_lstm_y_scaler.pkl', 'wb') as file:
    pickle.dump(y_scaler, file)
